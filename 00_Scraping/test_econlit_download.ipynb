# %%
import pandas as pd 
import numpy as np
import lxml
import traceback
from bs4 import BeautifulSoup as bs

# %%
test_download = open('econ_lit_xml/jpe_90-21.xml', 'r', encoding='utf-8')
content = test_download.read()
test_bs_content = bs(content, 'lxml')

# %%
candidate_list = test_bs_content.find_all('rec')
jpe_list = []
for candidate in candidate_list:
    try:
        journal_title = candidate.find('jtl').text
    except:
        print('failing out on record {}'.format(candidate.get('resultid')))
        continue
    if journal_title == "Journal of Political Economy":
        jpe_list.append(candidate)  
    else:
        print('failing out on record {}'.format(candidate.get('resultid')))

len(jpe_list)
# Out:
# 1798

# %%
xml_dict = {
    'doi' : 'ui',
    'title' : 'atl',
    'volume' : 'vid',
    'issue' : 'iid',
    'date' : 'dt',
    'abstract' : 'ab',
    'pages' : 'pages',
    'author' : 'au',
    'jel_desc' : 'su',
}


def field_population(temp_df, xml_obj, nav_dict, field):
    try:
        if field in ['jel_desc', 'author']:
            
            list_of = [desc.text for desc in xml_obj.find_all(nav_dict[field])]
            # print(list_of)
            temp_df.at[0,field] = list_of
            return temp_df

        value = xml_obj.find(nav_dict[field]).text
        temp_df[field] = value

        return temp_df
    except:
        # print('---------------------------------------')
        # print('fail on resultID {}, {}'.format(xml_obj.get('resultid'),field))
        value = 'ECONLIT None Found'
        temp_df[field] = value
        return temp_df
        # print(traceback.format_exc())


test_df = pd.DataFrame({

    })


for article in jpe_list:
    temp_df = pd.DataFrame({
        'doi' : [None],
        'title' : [None],
        'volume' : [None],
        'issue' : [None],
        'date' : [None],
        'abstract' : [None],
        'pages' : [None],
        'author' : [None],
        'jel_desc' : [None]
    })
    for field in xml_dict.keys():
        temp_df = field_population(temp_df, article, xml_dict, field)
    
    test_df = pd.concat([test_df, temp_df], ignore_index=True)

# %%
def insert_dash_date(string):
    try:
        listed = list(string)
        listed.insert(6, '-')
        listed.insert(4, '-')
        
        rejoined = ''.join(listed)
        return rejoined
    except:
        return string

test_df.date = test_df.date.apply(lambda x: insert_dash_date(x))
# test_df = test_df.explode('author')

# %%
jel_df = pd.read_xml('aea_jel_codes.xml', xpath='classification')

# %%
test_merge = test_df
test_merge['id'] = np.arange(len(test_merge))
# test_merge.set_index('id', inplace=True)

test_merge = test_merge.explode('jel_desc')

test_merge = pd.merge(test_merge, jel_df, how='left', left_on='jel_desc', right_on='description')

# test_merge.index.rename("index", inplace=True)
test_merge = test_merge.groupby(by='id').agg(
    {
        'jel_desc' : lambda x: x.tolist(),
        'code' : lambda x: x.tolist(),
        'doi' : lambda x: x.unique(),
        'title' : lambda x: x.unique(),
        'volume' : lambda x: x.unique(),
        'issue' : lambda x: x.unique(),
        'date' : lambda x: x.unique(),
        'pages' : lambda x: x.unique(),
        'author' : lambda x: x,
        'abstract' : lambda x: x,
    }
).rename({'code' : 'jel_code'}, axis=1)


test_merge = test_merge.explode('doi')
test_merge = test_merge.explode('title')
test_merge = test_merge.explode('volume')
test_merge = test_merge.explode('issue')
test_merge = test_merge.explode('date')
test_merge = test_merge.explode('pages')
# test_merge = test_merge.explode('author')

for row in test_merge.index.unique().tolist(): 
    try:
        test_merge.loc[row, 'author'] = test_merge.loc[row, 'author'][0]
        test_merge.loc[row, 'abstract'] = test_merge.loc[row, 'abstract'][0]
    except:
        # print(test_merge.loc[row, 'author'])
        print(test_merge.loc[row,'title'])


test_merge
# Out:
# Index to Volume 128.
# Index to Volume 127.
# Index to Volume 126.
# Back Cover.
# Recent Referees.
# Front Matter.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Front Matter.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Front Matter.
# 2021 Lucas Prize Announcement.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Front Matter.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Front Matter.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Front Matter.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# N.PAG.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Front Matter.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Front Matter.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Front Matter.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Front Matter.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Front Matter.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Front Matter.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Masthead.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Masthead.
# JPE Turnaround Times, Previous Two Years.
# Masthead.
# Back Cover.
# Recent Referees.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Masthead.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Masthead.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Masthead.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Masthead.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Masthead.
# JPE Turnaround Times, Previous Two Years.
# Back Cover.
# Recent Referees.
# Masthead.
# JPE Turnaround Times.
# Back Cover.
# Recent Referees.
# Masthead.
# JPE Turnaround Times, Previous Two Years.
# Masthead.
# Back Cover.
# Recent Referees.
# Masthead.
# Back Cover.
# Recent Referees.
# Masthead.
# Back Cover.
# Recent Referees.
# Masthead.
# Back Cover.
# Recent Referees.
# Masthead.
# Do Stock Prices Move Too Much to Be Justified by Subsequent Changes in Dividends?
# On the Nature of Transition Probabilities and Ergodic Sets in Markov Processes.
# The Role of Religion in Economic Trust.
# Arbitraging Nonlinear Sales Taxes.
# Diminishing Marginal Utility.
# The (Short) Monetary History of the Republic of Texas.
# Stigler's Theory of Optimal Law Enforcement in Thomas More's Utopia.
# Rolling Stones Down the Laffer Curve.
# Marlat Prices for Seminars.
# Property Rights and Botticelli's Solution to the Problem of Social Cost.
# Bentham and Marx Meet in the Tropics.
# The Distortionary Effects of Regulation and Rent Seeking.
# Signaling in the Qin Dynasty.
# JPE Data on Time to First Decision, 2002-2007.
# The Marriage Market in Babylonia according to Herodotus Histories.
# Stanley Kubrick on Team Incentives in Production.
# Galileo the Economist.
# Ancient Babylonian Stock Markets.
# The World According to Arthur Laffer, circa 1861.
# Perfect Competition and the Water-Toothpaste Paradox.
# Incentives at Cambridge in 1574.
# Averages, Marginals, and Father-Daughter Relationships.
# In memoriam: George J. Stigler.
# Is the Agent the Principle?
#                                                jel_desc  \
# id
# 0     [Trade Policy; International Trade Organizatio...
# 1     [Firm Behavior: Empirical Analysis, Empirical ...
# 2     [Consumer Economics: Empirical Analysis, Micro...
# 3     [Property Law, Energy, Environmental, Health, ...
# 4     [Portfolio Choice; Investment Decisions, Equit...
# ...                                                 ...
# 1793  [Economic Development Models and Theories, Hum...
# 1794  [Demographic Economics, Human Capital; Value o...
# 1795  [Economic Development Models and Theories, Dem...
# 1796         [Economic Development Models and Theories]
# 1797                                              [nan]
#
#                                  jel_code                 doi  \
# id
# 0                         [F13, F14, L80]  ECONLIT None Found
# 1     [D22, F14, F23, L14, L25, O31, O33]  ECONLIT None Found
# 2                    [D12, O12, Z12, Z13]  ECONLIT None Found
# 3               [K11, K32, P14, Q53, Q58]  ECONLIT None Found
# 4                         [G11, G12, G41]  ECONLIT None Found
# ...                                   ...                 ...
# 1793                           [nan, nan]  ECONLIT None Found
# 1794                           [nan, nan]  ECONLIT None Found
# 1795                      [nan, nan, nan]  ECONLIT None Found
# 1796                                [nan]  ECONLIT None Found
# 1797                                [nan]  ECONLIT None Found
#
#                                                   title volume issue  \
# id
# 0     The Economic Structure of International Trade-...    129     4
# 1     Upstream, Downstream: Diffusion and Impacts of...    129     4
# 2     How Do We Choose Our Identity? A Revealed Pref...    129     4
# 3                              Securing Property Rights    129     4
# 4                                         Asset Classes    129     4
# ...                                                 ...    ...   ...
# 1793                    Endogenous Technological Change     98     5
# 1794  Population Growth and Human Capital Investment...     98     5
# 1795      Human Capital, Fertility, and Economic Growth     98     5
# 1796           The Problem of Development: Introduction     98     5
# 1797                        Is the Agent the Principle?     98     2
#
#             date      pages  \
# id
# 0     2021-04-01  1287-1317
# 1     2021-04-01  1252-1286
# 2     2021-04-01  1193-1251
# 3     2021-04-01  1157-1192
# 4     2021-04-01  1100-1156
# ...          ...        ...
# 1793  1990-10-02    S71-102
# 1794  1990-10-02     S38-70
# 1795  1990-10-02     S12-37
# 1796  1990-10-02      S1-11
# 1797  1990-04-01    447-447
#
#                                                  author  \
# id
# 0                  [Staiger, Robert W., Sykes, Alan O.]
# 1                       [Basker, Emek, Simcoe, Timothy]
# 2       [Atkin, David, Colson-Sihra, Eve, Shayo, Moses]
# 3     [Behrer, A. Patrick, Glaeser, Edward L., Ponze...
# 4                                 [Jacquet, Nicolas L.]
# ...                                                 ...
# 1793                                   [Romer, Paul M.]
# 1794                              [Rosenzweig, Mark R.]
# 1795  [Becker, Gary S., Murphy, Kevin M., Tamura, Ro...
# 1796                                      Erlich, Isaac
# 1797                                                 []
#
#                                                abstract
# id
# 0     The existing economics literature on internati...
# 1     We study the adoption, diffusion, and impacts ...
# 2     Are identities fungible? How do people come to...
# 3     A central challenge in securing property right...
# 4     This paper proposes a theory of endogenous dif...
# ...                                                 ...
# 1793  Growth in this model is driven by technologica...
# 1794  This paper presents evidence from empirical st...
# 1795  The authors' analysis of growth assumes endoge...
# 1796                                                  E
# 1797                                 ECONLIT None Found
#
# [1798 rows x 10 columns]

# %%
# %store -r JPE_core_df
test_merge[test_merge.volume == '125']


sc_eho_try = pd.merge(JPE_core_df, test_merge,
     how='left',
      left_on=['sc_vol', 'sc_issue', 'sc_page_range'],
      right_on=['volume', 'issue', 'pages'])



sc_eho_try.to_csv('test_out.csv', index=False, encoding='utf-8')

# %%
sc_eho_try['title_match'] = 0
for row in sc_eho_try.index.tolist():
    if sc_eho_try.loc[row, 'sc_title'] == sc_eho_try.loc[row,'title']:
        sc_eho_try.loc[row, 'title_match'] = 1
    else:
        sc_eho_try.loc[row, 'title_match'] = 0

sc_eho_try.query('title_match == 1')
# Out:
#                doi_x                                           sc_title  \
# 130   10.1086/707011                                             Queens
# 360   10.1086/694632                  Memories of Friedman and Patinkin
# 372   10.1086/694623               Finance at the University of Chicago
# 499   10.1086/680415                                            Preface
# 592   10.1086/666746  The Schooling Decision: Family Preferences, In...
# 593   10.1086/666588  Moving Back Home: Insurance against Labor Mark...
# 594   10.1086/666655                 A Theory of Rational Jurisprudence
# 595   10.1086/666747  Capital Taxation: Quantitative Explorations of...
# 596   10.1086/666669  Illiquid Banks, Financial Stability, and Inter...
# 686   10.1086/599283        Information and the Skewness of Music Sales
# 1038  10.1086/317686            Comparative Politics and Public Finance
# 1122  10.1086/250049                                          Advocates
# 1137  10.1086/250075  Women's Schooling, Home Teaching, and Economic...
# 1164  10.1086/250019  The Theory of Sovereign Debt and Spain under P...
# 1167  10.1086/250029  Are Financial Analysts' Forecasts of Corporate...
# 1168  Endogenous Adverse Selection and Unemployment ...    106     4
# 1169  Rent Seeking with Bounded Rationality: An Anal...    106     4
# 1170                  The Macroeconomics of Specificity    106     4
# 1172  The Optimal Enforcement of Insider Trading Reg...    106     3
# 1173  Old-Age Longevity and Mortality-Contingent Claims    106     3
# 1176                      Goethe's Second-Price Auction    106     4
# 1181  Learning and Incentive-Compatible Mechanisms f...    106     3
#
#             date      pages  \
# 130   2020-07-01  2579-2652
# 360   2017-12-01  1831-1834
# 372   2017-12-01  1790-1799
# 499   2015-04-01    263-265
# 592   2012-06-01    359-397
# 593   2012-06-01    446-512
# 594   2012-06-01    513-551
# 595   2012-06-01    398-445
# 596   2012-06-01    552-591
# 686   2009-04-01    324-369
# 1038  2000-12-01  1121-1161
# 1122  1999-02-01       1-39
# 1137  1999-08-01    682-714
# 1164  1998-06-01    483-513
# 1167  1998-08-01    768-805
# 1168  1998-08-01    806-827
# 1169  1998-08-01    828-853
# 1170  1998-08-01    724-767
# 1172  1998-06-01    602-632
# 1173  1998-06-01    551-573
# 1176  1998-08-01    854-859
# 1181  1998-06-01    633-662
#
#                                                  author  \
# 130                    [Dube, Oeindrila, Harish, S. P.]
# 360                             [Lucas, Robert E., Jr.]
# 372                                   [Fama, Eugene F.]
# 499                                       Cunha, Flavio
# 592             [Bursztyn, Leonardo, Coffman, Lucas C.]
# 593                                      [Kaplan, Greg]
# 594                   [Baker, Scott, Mezzetti, Claudio]
# 595                    [Farhi, Emmanuel, Werning, Ivan]
# 596           [Diamond, Douglas W., Rajan, Raghuram G.]
# 686                    [Hendricks, Ken, Sorensen, Alan]
# 1038  [Persson, Torsten, Roland, Gerard, Tabellini, ...
# 1122               [Dewatripont, Mathias, Tirole, Jean]
# 1137                                 [Behrman, Jere R.]
# 1164                                   [Conklin, James]
# 1167              [Keane, Michael P., Runkle, David E.]
# 1168                       [Chiu, W. Henry, Karni, Edi]
# 1169  [Anderson, Simon P., Goeree, Jacob K., Holt, C...
# 1170       [Caballero, Ricardo J., Hammour, Mohamad L.]
# 1172                                  DeMarzo, Peter M.
# 1173             [Philipson, Tomas J., Becker, Gary S.]
# 1176                                   Moldovanu, Benny
# 1181                       [Chen, Yan, Tang, Fang-Fang]
#
#                                                abstract title_match
# 130   Do states experience more peace under female l...           1
# 360                                  ECONLIT None Found           1
# 372                                  ECONLIT None Found           1
# 499                                                   E           1
# 592   This paper experimentally analyzes the schooli...           1
# 593   This paper demonstrates that the option to mov...           1
# 594   We examine a dynamic model of up-or-down probl...           1
# 595   Economies with private information provide a r...           1
# 596   Banks finance illiquid assets with demandable ...           1
# 686   This paper studies the role of product discove...           1
# 1038  We propose a model with micropolitical foundat...           1
# 1122  This paper provides a rationale for advocacy. ...           1
# 1137  The hypothesis that increases in the schooling...           1
# 1164  This paper examines lending by a Genoese-led c...           1
# 1167  This paper develops generalized method-of-mome...           1
# 1168  In this paper, the authors consider how the pr...           1
# 1169  The winner-take-all nature of all-pay auctions...           1
# 1170  Specific quasi-rents arise in a variety of eco...           1
# 1172                                                  R           1
# 1173  This paper analyzes the savings and longevity ...           1
# 1176                                                  I           1
# 1181  This is the first systematic experimental stud...           1
#
# [22 rows x 23 columns]
