# %%
import pandas as pd
import numpy as np
import os
import json
import requests

# %%
keys_json = json.load(open('env_keys.json'))
scopus_key = keys_json['scopus_key']
req_headers = {
    'X-ELS-APIKey' : scopus_key
}

# %%
firstname = 'john'
lastname = 'smith'
author_search_params = {
    'httpAccept'  : 'application/json',
    'query' : 'AUTHFIRST({}) AND AUTHLASTNAME({}) AND SUBJAREA(ECON)'.format(firstname, lastname)
}
author_search_params
# Out:
# {'httpAccept': 'application/json',
#  'query': 'AUTHFIRST(john) AND AUTHLASTNAME(smith) AND SUBJAREA(ECON)'}

# %%
response = requests.get(
    url='https://api.elsevier.com/content/search/author',
    headers=req_headers,
    params=author_search_params
)

# %%
response.json().get('search-results').keys()
# Out:
# dict_keys(['opensearch:totalResults', 'opensearch:startIndex', 'opensearch:itemsPerPage', 'opensearch:Query', 'link', 'entry'])

# %%
response.json().get('search-results').get('entry')[0]
# Out:
# {'@_fa': 'true',
#  'link': [{'@_fa': 'true',
#    '@ref': 'self',
#    '@href': 'https://api.elsevier.com/content/author/author_id/55498586200'},
#   {'@_fa': 'true',
#    '@ref': 'search',
#    '@href': 'https://api.elsevier.com/content/search/author?query=au-id%2855498586200%29'},
#   {'@_fa': 'true',
#    '@ref': 'scopus-citedby',
#    '@href': 'https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=55498586200&origin=inward'},
#   {'@_fa': 'true',
#    '@ref': 'scopus-author',
#    '@href': 'https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=55498586200&origin=inward'}],
#  'prism:url': 'https://api.elsevier.com/content/author/author_id/55498586200',
#  'dc:identifier': 'AUTHOR_ID:55498586200',
#  'eid': '9-s2.0-55498586200',
#  'preferred-name': {'surname': 'Smith',
#   'given-name': 'Andrew John',
#   'initials': 'A.J.'},
#  'name-variant': [{'@_fa': 'true',
#    'surname': 'Smith',
#    'given-name': 'Andy',
#    'initials': 'A.'},
#   {'@_fa': 'true', 'surname': 'Smith', 'given-name': 'A.', 'initials': 'A.'},
#   {'@_fa': 'true',
#    'surname': 'Smith',
#    'given-name': 'Andrew J.',
#    'initials': 'A.J.'}],
#  'document-count': '232',
#  'subject-area': [{'@abbrev': 'MEDI',
#    '@frequency': '191',
#    '$': 'Medicine (all)'},
#   {'@abbrev': 'DENT', '@frequency': '80', '$': 'Dentistry (all)'},
#   {'@abbrev': 'IMMU',
#    '@frequency': '57',
#    '$': 'Immunology and Microbiology (all)'}],
#  'affiliation-current': {'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60001490',
#   'affiliation-id': '60001490',
#   'affiliation-name': 'University of Glasgow',
#   'affiliation-city': 'Glasgow',
#   'affiliation-country': 'United Kingdom'}}

# %%
def constructAliases(firstname, lastname, initials):
    #First Last
    x = firstname + ' ' + lastname
    # Initials Last
    y = initials + ' ' + lastname
    return [x, y]

# %%
aliases_dict = {}
for i, author_object in enumerate(response.json().get('search-results').get('entry')):
    scopus_id = author_object.get('dc:identifier').split(':')[1]
    print(scopus_id)
    aliases_dict[scopus_id] = []
    author_object_preferred_name_obj = author_object.get('preferred-name')
    print('Preferred name fields: {}'.format(i))
    surname = author_object_preferred_name_obj.get('surname')
    givenname = author_object_preferred_name_obj.get('given-name')
    initials = author_object_preferred_name_obj.get('initials')
    print('\t{}'.format(surname))
    print('\t{}'.format(givenname))
    print('\t{}'.format(initials))
    aliases_dict[scopus_id].append(constructAliases(givenname, surname, initials))

    author_object_name_variant_obj = author_object.get('name-variant')
    if author_object_name_variant_obj == None:
        print('nothing to see here')
    elif type(author_object_name_variant_obj) == list: 
        for j, name_variant_object in enumerate(author_object_name_variant_obj):


            variant_surname = name_variant_object.get('surname')
            variant_givenname = name_variant_object.get('given-name')
            variant_initials = name_variant_object.get('initials')
            print('Name variant fields: {}-{}'.format(i,j))
            print('\t{}'.format(variant_surname))
            print('\t{}'.format(variant_givenname))
            print('\t{}'.format(variant_initials))
            aliases_dict[scopus_id].append(constructAliases(variant_givenname, variant_surname, variant_initials))
    
    aliases_dict[scopus_id] = set(sum(aliases_dict[scopus_id], []))
    print(aliases_dict)
# Out:
# 55498586200
# Preferred name fields: 0
# 	Smith
# 	Andrew John
# 	A.J.
# Name variant fields: 0-0
# 	Smith
# 	Andy
# 	A.
# Name variant fields: 0-1
# 	Smith
# 	A.
# 	A.
# Name variant fields: 0-2
# 	Smith
# 	Andrew J.
# 	A.J.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}}
# 7501693900
# Preferred name fields: 1
# 	Smith
# 	Ben J.
# 	B.J.
# Name variant fields: 1-0
# 	Smith
# 	Ben John
# 	B.J.
# Name variant fields: 1-1
# 	Smith
# 	Ben
# 	B.
# Name variant fields: 1-2
# 	Smith
# 	B. J.
# 	B.J.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}}
# 55911705800
# Preferred name fields: 2
# 	Russell-Smith
# 	Jeremy
# 	J.
# Name variant fields: 2-0
# 	Russell-Smith
# 	J. C.Z.
# 	J.C.Z.
# Name variant fields: 2-1
# 	Russell Smith
# 	Jr
# 	J.
# Name variant fields: 2-2
# 	Russell Smith
# 	Jeremy
# 	J.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}}
# 55722939900
# Preferred name fields: 3
# 	Smith
# 	David J.
# 	D.J.
# Name variant fields: 3-0
# 	Smith
# 	Dave J.
# 	D.J.
# Name variant fields: 3-1
# 	Smith
# 	D.
# 	D.
# Name variant fields: 3-2
# 	Smith
# 	David J.
# 	D.J.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}}
# 35303305900
# Preferred name fields: 4
# 	Smith
# 	John Stephen C.
# 	J.S.C.
# Name variant fields: 4-0
# 	Smith
# 	Stephen
# 	S.
# Name variant fields: 4-1
# 	Smith
# 	J. S.
# 	J.S.
# Name variant fields: 4-2
# 	Smith
# 	Steven Rathgeb
# 	S.R.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}}
# 7410165641
# Preferred name fields: 5
# 	Smith
# 	John V.
# 	J.V.
# Name variant fields: 5-0
# 	Smith
# 	John Victor
# 	J.V.
# Name variant fields: 5-1
# 	Smith
# 	J. V.
# 	J.V.
# Name variant fields: 5-2
# 	Smith
# 	John
# 	J.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}}
# 57212401677
# Preferred name fields: 6
# 	Smith
# 	Nigel John
# 	N.J.
# Name variant fields: 6-0
# 	Smith
# 	Nigel J.
# 	N.J.
# Name variant fields: 6-1
# 	Smith
# 	Nigel
# 	N.
# Name variant fields: 6-2
# 	Smith
# 	N. J.
# 	N.J.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}}
# 36653119800
# Preferred name fields: 7
# 	Smith
# 	Richard John
# 	R.J.
# Name variant fields: 7-0
# 	Smith
# 	Richard
# 	R.
# Name variant fields: 7-1
# 	Smith
# 	Richard J.
# 	R.J.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}}
# 57201049133
# Preferred name fields: 8
# 	Smith
# 	John
# 	J.
# nothing to see here
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}}
# 16409518800
# Preferred name fields: 9
# 	Smith
# 	John E.
# 	J.E.
# Name variant fields: 9-0
# 	SMITH
# 	JOHN
# 	J.
# Name variant fields: 9-1
# 	SMITH
# 	JOHN E.
# 	J.E.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}}
# 11340202400
# Preferred name fields: 10
# 	Smith
# 	Jason B.
# 	J.B.
# Name variant fields: 10-0
# 	Smith
# 	J. B.
# 	J.B.
# Name variant fields: 10-1
# 	Smith
# 	Jason
# 	J.
# Name variant fields: 10-2
# 	Smith
# 	J.
# 	J.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}}
# 6508139609
# Preferred name fields: 11
# 	Milton-Smith
# 	John
# 	J.
# nothing to see here
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}}
# 57193096409
# Preferred name fields: 12
# 	Smith
# 	Simon John
# 	S.J.
# Name variant fields: 12-0
# 	Smith
# 	Simon J.
# 	S.J.
# Name variant fields: 12-1
# 	Smith
# 	Simon
# 	S.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}}
# 7410169008
# Preferred name fields: 13
# 	Smith
# 	John C.
# 	J.C.
# nothing to see here
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}}
# 7410180119
# Preferred name fields: 14
# 	Smith
# 	John Grieve
# 	J.G.
# nothing to see here
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}, '7410180119': {'J.G. Smith', 'John Grieve Smith'}}
# 7410171086
# Preferred name fields: 15
# 	Smith
# 	John T.
# 	J.T.
# Name variant fields: 15-0
# 	Smith
# 	John
# 	J.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}, '7410180119': {'J.G. Smith', 'John Grieve Smith'}, '7410171086': {'John Smith', 'John T. Smith', 'J. Smith', 'J.T. Smith'}}
# 36593596400
# Preferred name fields: 16
# 	Smith
# 	John Masson
# 	J.M.
# Name variant fields: 16-0
# 	Smith
# 	John M.
# 	J.M.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}, '7410180119': {'J.G. Smith', 'John Grieve Smith'}, '7410171086': {'John Smith', 'John T. Smith', 'J. Smith', 'J.T. Smith'}, '36593596400': {'John M. Smith', 'John Masson Smith', 'J.M. Smith'}}
# 56103924800
# Preferred name fields: 17
# 	Smith
# 	John Z.
# 	J.Z.
# nothing to see here
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}, '7410180119': {'J.G. Smith', 'John Grieve Smith'}, '7410171086': {'John Smith', 'John T. Smith', 'J. Smith', 'J.T. Smith'}, '36593596400': {'John M. Smith', 'John Masson Smith', 'J.M. Smith'}, '56103924800': {'John Z. Smith', 'J.Z. Smith'}}
# 55219708800
# Preferred name fields: 18
# 	Masson Smith
# 	John
# 	J.
# Name variant fields: 18-0
# 	Masson smith
# 	John
# 	J.
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}, '7410180119': {'J.G. Smith', 'John Grieve Smith'}, '7410171086': {'John Smith', 'John T. Smith', 'J. Smith', 'J.T. Smith'}, '36593596400': {'John M. Smith', 'John Masson Smith', 'J.M. Smith'}, '56103924800': {'John Z. Smith', 'J.Z. Smith'}, '55219708800': {'J. Masson smith', 'John Masson Smith', 'J. Masson Smith', 'John Masson smith'}}
# 7410169735
# Preferred name fields: 19
# 	Smith
# 	John F.
# 	J.F.
# nothing to see here
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}, '7410180119': {'J.G. Smith', 'John Grieve Smith'}, '7410171086': {'John Smith', 'John T. Smith', 'J. Smith', 'J.T. Smith'}, '36593596400': {'John M. Smith', 'John Masson Smith', 'J.M. Smith'}, '56103924800': {'John Z. Smith', 'J.Z. Smith'}, '55219708800': {'J. Masson smith', 'John Masson Smith', 'J. Masson Smith', 'John Masson smith'}, '7410169735': {'J.F. Smith', 'John F. Smith'}}
# 57256506100
# Preferred name fields: 20
# 	Smith
# 	John
# 	J.
# nothing to see here
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}, '7410180119': {'J.G. Smith', 'John Grieve Smith'}, '7410171086': {'John Smith', 'John T. Smith', 'J. Smith', 'J.T. Smith'}, '36593596400': {'John M. Smith', 'John Masson Smith', 'J.M. Smith'}, '56103924800': {'John Z. Smith', 'J.Z. Smith'}, '55219708800': {'J. Masson smith', 'John Masson Smith', 'J. Masson Smith', 'John Masson smith'}, '7410169735': {'J.F. Smith', 'John F. Smith'}, '57256506100': {'John Smith', 'J. Smith'}}
# 57214611971
# Preferred name fields: 21
# 	Smith-Hill
# 	John
# 	J.
# nothing to see here
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}, '7410180119': {'J.G. Smith', 'John Grieve Smith'}, '7410171086': {'John Smith', 'John T. Smith', 'J. Smith', 'J.T. Smith'}, '36593596400': {'John M. Smith', 'John Masson Smith', 'J.M. Smith'}, '56103924800': {'John Z. Smith', 'J.Z. Smith'}, '55219708800': {'J. Masson smith', 'John Masson Smith', 'J. Masson Smith', 'John Masson smith'}, '7410169735': {'J.F. Smith', 'John F. Smith'}, '57256506100': {'John Smith', 'J. Smith'}, '57214611971': {'John Smith-Hill', 'J. Smith-Hill'}}
# 57210448704
# Preferred name fields: 22
# 	Smith
# 	John Meredith
# 	J.M.
# nothing to see here
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}, '7410180119': {'J.G. Smith', 'John Grieve Smith'}, '7410171086': {'John Smith', 'John T. Smith', 'J. Smith', 'J.T. Smith'}, '36593596400': {'John M. Smith', 'John Masson Smith', 'J.M. Smith'}, '56103924800': {'John Z. Smith', 'J.Z. Smith'}, '55219708800': {'J. Masson smith', 'John Masson Smith', 'J. Masson Smith', 'John Masson smith'}, '7410169735': {'J.F. Smith', 'John F. Smith'}, '57256506100': {'John Smith', 'J. Smith'}, '57214611971': {'John Smith-Hill', 'J. Smith-Hill'}, '57210448704': {'John Meredith Smith', 'J.M. Smith'}}
# 57201337739
# Preferred name fields: 23
# 	Smith
# 	John
# 	J.
# nothing to see here
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}, '7410180119': {'J.G. Smith', 'John Grieve Smith'}, '7410171086': {'John Smith', 'John T. Smith', 'J. Smith', 'J.T. Smith'}, '36593596400': {'John M. Smith', 'John Masson Smith', 'J.M. Smith'}, '56103924800': {'John Z. Smith', 'J.Z. Smith'}, '55219708800': {'J. Masson smith', 'John Masson Smith', 'J. Masson Smith', 'John Masson smith'}, '7410169735': {'J.F. Smith', 'John F. Smith'}, '57256506100': {'John Smith', 'J. Smith'}, '57214611971': {'John Smith-Hill', 'J. Smith-Hill'}, '57210448704': {'John Meredith Smith', 'J.M. Smith'}, '57201337739': {'John Smith', 'J. Smith'}}
# 57199014279
# Preferred name fields: 24
# 	Smith
# 	John Grieve
# 	J.G.
# nothing to see here
# {'55498586200': {'A.J. Smith', 'A. Smith', 'Andrew John Smith', 'Andrew J. Smith', 'Andy Smith'}, '7501693900': {'B.J. Smith', 'B. J. Smith', 'Ben J. Smith', 'Ben John Smith', 'B. Smith', 'Ben Smith'}, '55911705800': {'J. Russell Smith', 'Jr Russell Smith', 'J. C.Z. Russell-Smith', 'Jeremy Russell Smith', 'Jeremy Russell-Smith', 'J. Russell-Smith', 'J.C.Z. Russell-Smith'}, '55722939900': {'D.J. Smith', 'D. Smith', 'David J. Smith', 'Dave J. Smith'}, '35303305900': {'John Stephen C. Smith', 'S.R. Smith', 'J. S. Smith', 'J.S.C. Smith', 'J.S. Smith', 'S. Smith', 'Stephen Smith', 'Steven Rathgeb Smith'}, '7410165641': {'John Smith', 'J. Smith', 'John Victor Smith', 'John V. Smith', 'J. V. Smith', 'J.V. Smith'}, '57212401677': {'N. Smith', 'N. J. Smith', 'N.J. Smith', 'Nigel Smith', 'Nigel J. Smith', 'Nigel John Smith'}, '36653119800': {'Richard J. Smith', 'R.J. Smith', 'Richard John Smith', 'Richard Smith', 'R. Smith'}, '57201049133': {'John Smith', 'J. Smith'}, '16409518800': {'John E. Smith', 'JOHN SMITH', 'JOHN E. SMITH', 'J. SMITH', 'J.E. Smith', 'J.E. SMITH'}, '11340202400': {'J. B. Smith', 'J. Smith', 'Jason Smith', 'J.B. Smith', 'Jason B. Smith'}, '6508139609': {'John Milton-Smith', 'J. Milton-Smith'}, '57193096409': {'Simon John Smith', 'S.J. Smith', 'Simon Smith', 'S. Smith', 'Simon J. Smith'}, '7410169008': {'J.C. Smith', 'John C. Smith'}, '7410180119': {'J.G. Smith', 'John Grieve Smith'}, '7410171086': {'John Smith', 'John T. Smith', 'J. Smith', 'J.T. Smith'}, '36593596400': {'John M. Smith', 'John Masson Smith', 'J.M. Smith'}, '56103924800': {'John Z. Smith', 'J.Z. Smith'}, '55219708800': {'J. Masson smith', 'John Masson Smith', 'J. Masson Smith', 'John Masson smith'}, '7410169735': {'J.F. Smith', 'John F. Smith'}, '57256506100': {'John Smith', 'J. Smith'}, '57214611971': {'John Smith-Hill', 'J. Smith-Hill'}, '57210448704': {'John Meredith Smith', 'J.M. Smith'}, '57201337739': {'John Smith', 'J. Smith'}, '57199014279': {'J.G. Smith', 'John Grieve Smith'}}

# %%
response.json().get('search-results').get('entry')[0].keys()
# Out:
# dict_keys(['@_fa', 'link', 'prism:url', 'dc:identifier', 'eid', 'preferred-name', 'name-variant', 'document-count', 'subject-area', 'affiliation-current'])

# %%
import re
authors_abstracts_df = pd.DataFrame()
filenames = os.listdir('scopus_data')
path_prepend = 'scopus_data/'
for filename in filenames:
    if re.search(r'_author_abstract_funding\.csv', filename):
        file_path = path_prepend + filename
        print(file_path)
        journal_authors_abstracts_df = pd.read_csv(file_path)
        authors_abstracts_df = pd.concat([authors_abstracts_df, journal_authors_abstracts_df])

print(len(authors_abstracts_df))
authors_abstracts_df
# Out:
# scopus_data/AER_author_abstract_funding.csv
# C:\Users\Joshualevy\AppData\Local\Temp\ipykernel_21284\1680617075.py:9: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   journal_authors_abstracts_df = pd.read_csv(file_path)
# scopus_data/ALJ_author_abstract_funding.csv
# scopus_data/ATB_author_abstract_funding.csv
# scopus_data/ATX_author_abstract_funding.csv
# scopus_data/ECA_author_abstract_funding.csv
# scopus_data/ECX_author_abstract_funding.csv
# scopus_data/JEM_author_abstract_funding.csv
# scopus_data/JFE_author_abstract_funding.csv
# scopus_data/JHR_author_abstract_funding.csv
# scopus_data/JLE_author_abstract_funding.csv
# scopus_data/JLO_author_abstract_funding.csv
# scopus_data/JOF_author_abstract_funding.csv
# scopus_data/JOL_author_abstract_funding.csv
# scopus_data/JPE_author_abstract_funding.csv
# scopus_data/QJE_author_abstract_funding.csv
# scopus_data/RES_author_abstract_funding.csv
# scopus_data/RFS_author_abstract_funding.csv
# scopus_data/RJE_author_abstract_funding.csv
# 682578
#                                  doi  \
# 0               10.1257/aer.20201238
# 1               10.1257/aer.20181801
# 2     10.9767/BCREC.17.1.12473.22-31
# 3     10.9767/BCREC.17.1.12366.32-45
# 4      10.9767/BCREC.17.1.12174.1-12
# ...                              ...
# 2207                 10.2307/2601057
# 2208                 10.2307/2601018
# 2209                 10.2307/2601017
# 2210                 10.2307/2601017
# 2211                 10.2307/2601006
#
#                                                sc_title  sc_issn  \
# 0     Team- Specific Human Capital and Team Performa...    28282
# 1     Prep School for Poor Kids: The Long- Run Impac...    28282
# 2     Team-Specific Human Capital and Team Performan...    28282
# 3     M Equilibrium: A Theory of Beliefs and Choices...    28282
# 4       Sectoral Media Focus and Aggregate Fluctuations    28282
# ...                                                 ...      ...
# 2207  The supply of charity services by nonprofit ho...  7416261
# 2208      Uncertain litigation and liability insurance.  7416261
# 2209  Medical malpractice: an empirical examination ...  7416261
# 2210  Medical malpractice: an empirical examination ...  7416261
# 2211  The interaction between forms of insurance con...  7416261
#
#                         sc_pub_name sc_vol sc_issue sc_page_range  \
# 0          American Economic Review    111       12     3923-3962
# 1          American Economic Review    111       12     3963-4001
# 2          American Economic Review    111       12     3923-3962
# 3          American Economic Review    111       12     4002-4045
# 4          American Economic Review    111       12     3872-3922
# ...                             ...    ...      ...           ...
# 2207  The Rand journal of economics     22        3       430-445
# 2208  The Rand journal of economics     22        2       218-231
# 2209  The Rand journal of economics     22        2       199-217
# 2210  The Rand journal of economics     22        2       199-217
# 2211  The Rand journal of economics     22        1         36-53
#
#                                sc_abstract_api_endpoint  \
# 0     https://api.elsevier.com/content/abstract/scop...
# 1     https://api.elsevier.com/content/abstract/scop...
# 2     https://api.elsevier.com/content/abstract/scop...
# 3     https://api.elsevier.com/content/abstract/scop...
# 4     https://api.elsevier.com/content/abstract/scop...
# ...                                                 ...
# 2207  https://api.elsevier.com/content/abstract/scop...
# 2208  https://api.elsevier.com/content/abstract/scop...
# 2209  https://api.elsevier.com/content/abstract/scop...
# 2210  https://api.elsevier.com/content/abstract/scop...
# 2211  https://api.elsevier.com/content/abstract/scop...
#
#                                            sc_human_url sc_pub_date  ...  \
# 0     https://www.scopus.com/inward/citedby.uri?part...  2021-12-01  ...
# 1     https://www.scopus.com/inward/citedby.uri?part...  2021-12-01  ...
# 2     https://www.scopus.com/inward/citedby.uri?part...  2021-12-01  ...
# 3     https://www.scopus.com/inward/citedby.uri?part...  2021-12-01  ...
# 4     https://www.scopus.com/inward/citedby.uri?part...  2021-12-01  ...
# ...                                                 ...         ...  ...
# 2207  https://www.scopus.com/inward/citedby.uri?part...  1991-01-01  ...
# 2208  https://www.scopus.com/inward/citedby.uri?part...  1991-01-01  ...
# 2209  https://www.scopus.com/inward/citedby.uri?part...  1991-01-01  ...
# 2210  https://www.scopus.com/inward/citedby.uri?part...  1991-01-01  ...
# 2211  https://www.scopus.com/inward/citedby.uri?part...  1991-01-01  ...
#
#        sc_author_id sc_author_given_name sc_author_last_name  \
# 0     57388639400.0                Yiqun                Chen
# 1     14631703900.0            Martha J.              Bailey
# 2     57388639400.0                Yiqun                Chen
# 3      7003736000.0             Jacob K.              Goeree
# 4     36666132400.0                 Ryan            Chahrour
# ...             ...                  ...                 ...
# 2207   7004310598.0                D. S.            Salkever
# 2208   6603642202.0                   B.              Sarath
# 2209   7005716141.0                H. S.              Farber
# 2210   7404176354.0                M. J.               White
# 2211  56698488700.0                J. R.         Baumgardner
#
#      sc_author_affil_id                            sc_author_affil_indexed  \
# 0              60027561                  University of Illinois at Chicago
# 1              60027550  Department of Economics, University of Califor...
# 2              60027561                  University of Illinois at Chicago
# 3              60028333               AGORA Center for Market Design, UNSW
# 4              60031117               Economics Department, Boston College
# ...                 ...                                                ...
# 2207           60005248                                     SCOPUS FAILURE
# 2208           60006297                                     SCOPUS FAILURE
# 2209           60022195                                     SCOPUS FAILURE
# 2210           60022195                                     SCOPUS FAILURE
# 2211           60008724                                     SCOPUS FAILURE
#
#                                           sc_grant_text  \
# 0                                        SCOPUS FAILURE
# 1                                        SCOPUS FAILURE
# 2     I gratefully acknowledge support from the Leon...
# 3     We gratefully acknowledge funding from the Aus...
# 4                                        SCOPUS FAILURE
# ...                                                 ...
# 2207                                                NaN
# 2208                                     SCOPUS FAILURE
# 2209                                     SCOPUS FAILURE
# 2210                                                NaN
# 2211                                     SCOPUS FAILURE
#
#                                         sc_funding_text sc_funding_agency  \
# 0     * University of Illinois at Chicago (email: yq...    SCOPUS FAILURE
# 1     * Bailey: Department of Economics, University ...    SCOPUS FAILURE
# 2     * University of Illinois at Chicago (email: yq...    SCOPUS FAILURE
# 3     * Goeree: AGORA Center for Market Design, UNSW...    SCOPUS FAILURE
# 4                                        SCOPUS FAILURE    SCOPUS FAILURE
# ...                                                 ...               ...
# 2207                                                NaN               NaN
# 2208                                     SCOPUS FAILURE    SCOPUS FAILURE
# 2209                                     SCOPUS FAILURE    SCOPUS FAILURE
# 2210                                                NaN               NaN
# 2211                                     SCOPUS FAILURE    SCOPUS FAILURE
#
#      sc_author_indexed_name                                   sc_abstract_text
# 0                   Chen Y.  © 2021 American Economic Association. All righ...
# 1               Bailey M.J.  © 2021 American Economic Association. All righ...
# 2                   Chen Y.  © 2021 American Economic Association. All righ...
# 3               Goeree J.K.  © 2021 American Economic Association. All righ...
# 4               Chahrour R.  © 2021 American Economic Association. All righ...
# ...                     ...                                                ...
# 2207            Salkever D.  This article studies provision of charity care...
# 2208              Sarath B.  Legal penalties and liability insurance seem t...
# 2209              Farber H.  New data on medical malpractice claims against...
# 2210               White M.  New data on medical malpractice claims against...
# 2211         Baumgardner J.  A simple three-parameter description of medica...
#
# [682578 rows x 22 columns]

# %%
unique_authors = authors_abstracts_df.unique(subset=['scopus_author_id', ])
