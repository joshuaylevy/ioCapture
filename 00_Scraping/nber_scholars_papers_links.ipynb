# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np
import re
import math
import time
import random

# %%
scholars_df = pd.read_csv('nber_affiliated_scholars.csv', index_col=None)
scholars_df = scholars_df.drop(columns=['index'])

# %%
proxies_list_scrambled = open('proxies.txt', 'r').readlines()
proxies_list_split = list(map(lambda x: x.split(':'), proxies_list_scrambled))
proxies_list_cleaned = list(map(lambda x: 'http://{}:{}@{}:{}'.format(x[2],x[3], x[0], x[1]), proxies_list_split))

# %%
def get_total_expected_papers(response_json):
    total_expected_papers = response_json.get('totalResults')
    return total_expected_papers

# %%
def response_to_df(input_df, json_response):
    api_results = json_response.get('results')
    temp_df = pd.DataFrame.from_records(api_results)
    output_df = pd.concat([input_df, temp_df], ignore_index=True)
    return output_df

# %%
def get_papers_by_api(url, existing_df):
    response = requests.get(url, proxies=generate_random_proxy_tunnel())
    if response.status_code == 200:
        response_json = response.json()
        new_df = response_to_df(existing_df, response_json)

        try:
            print("\tSUCCESS")
            return new_df
        except Exception as e:
            e.raiseExceptions
    else:
        print('FAILING OUT JSON RESPONSE FAILED ON: {}'.format(url))

# %%
def generate_random_proxy_tunnel():
    ### IT APPEARS THAT ONLY THE FIRST 100 PROXY SERVERS ARE WORKING?
    rand_proxy = proxies_list_cleaned[np.random.choice(np.arange(1,100))]
    proxy_obj = {'https' : rand_proxy}
    return proxy_obj

# %%
api_call_template_url = 'https://www.nber.org/api/v1/generic_listing/uid/{}/contentType,contentType,contentType,contentType,contentType,contentType,contentType,contentType/working_paper,book,chapter,dataset,interview,lecture,center_paper,article/search?page=1&perPage=100'

all_papers_df = pd.DataFrame()
for row in scholars_df.index.tolist():  
    scholar_df = pd.DataFrame()
    scholar_name = scholars_df.loc[row, 'name']
    scholar_uid = scholars_df.loc[row, 'id']
    scholar_effective_id = re.search(r'\d+', scholars_df.loc[row, 'id']).group()

    api_call_url = api_call_template_url.format(scholar_effective_id)

    try:
        random_proxy = generate_random_proxy_tunnel()
        init_response = requests.get(api_call_url, proxies=random_proxy)
    except:
        print('FAILED A REQUEST WHEN USING PROXY SERVER: {}'.format(random_proxy))

    init_response_json = init_response.json()
    if init_response.status_code == 200:
        expected_total_papers = get_total_expected_papers(init_response_json)
        print('NUMBER OF TOTAL WORK PRODUCTS AS BEING AFFILIATED WITH {}: {}'.format(scholar_name.upper(), expected_total_papers))
    else:
        print("FAILING OUT JSON RESPONSE FAILED ON: {}".format(api_call_url))

    scholar_df = response_to_df(scholar_df, init_response_json)

    page_number = 1
    expected_total_pages = int(math.ceil(expected_total_papers / 100))
    while len(scholar_df) < expected_total_papers:
        page_number += 1
        new_url = re.sub(r'page=\d', r'page=' + str(page_number), api_call_url)
        print('ATTEMPTING TO CALL ON {} PAGE {this}/{total}'.format(scholar_name.upper(), this=page_number, total=expected_total_pages))
        scholar_df = get_papers_by_api(new_url, scholar_df)


    scholar_df['assigned_author'] = scholar_name
    scholar_df['assigned_author_uid'] = scholar_uid
    random_sleep_interval = random.randint(1,10)
    all_papers_df = pd.concat([all_papers_df, scholar_df], ignore_index=True)
    # print('SLEEPING FOR {} SECONDS'.format(random_sleep_interval))
    time.sleep(random_sleep_interval/10)
    print('COMPLETED {this}/{total} SCHOLARS (NB some scholars may require multiple calls)'.format(this=row, total=len(scholars_df)))



print("NUMBER OF ALL NBER WORK PRODUCTS IDENTIFIED: {}".format(len(all_papers_df)))
all_papers_df = all_papers_df[all_papers_df.displaytypename == 'Working Paper']
print("NUMBER OF ALL NBER WORKING PAPERS IDENTIFIED: {}".format(len(all_papers_df)))

# %%
### SET UP BEFORE ADVANCING TO DOWNLOADING PAPERS: 
all_papers_df = pd.read_csv('nber_affiliated_scholar_paper.csv')
all_papers_df['page_url'] = None
all_papers_df['pdf_url'] = None

all_papers_df['abstract'] = None
all_papers_df['disclosures'] = None
all_papers_df['doi'] = None
all_papers_df['issue_date'] = None

# all_papers_df.reset_index(inplace=True)
all_papers_df.to_csv('nber_affiliated_scholar_paper.csv', index=False, encoding='utf-8')

# %%
def check_for_previous_collection(page_url, df, row):
    sub_df = df.head(row)
    if page_url in sub_df.page_url.tolist():
        return True, df.loc[row, :]
    else:
        return False, None

# %%
all_papers_df = pd.read_csv('nber_affiliated_scholar_paper.csv')
# IF WE HAVE A FAILURE PART WAY THROUGH USE THE FOLLOWING READ INSTEAD OF THE ABOVE:
# all_papers_df = pd.read_csv('all_papers_df_temp_backup.csv')

for row in all_papers_df.index.tolist():
    print(row)
    # if all_papers_df.loc[row, 'page_url'] is not None:
        
    #     print('a)ALREADY DOWNLOADED ROW {}.... PROCEEDING'.format(row))
    #     print(all_papers_df.loc[row, 'page_url'])
    #     continue
    if type(all_papers_df.loc[row, 'page_url']) is str:
        print('b) ALREADY DOWNLOADED ROW {}.... PROCEEDING'.format(row))
        continue
    else:
        print('HAVE YET TO DO DOWNLOAD FOR ROW {}'.format(row))
        # print(all_papers_df.loc[row, :])

    url = all_papers_df.loc[row, 'url']
    print(url)

    working_paper_code = re.search(r'(w|t|h)\d+', url).group()
    page_url = 'https://www.nber.org' + url
    pdf_url = 'https://www.nber.org/system/files/working_papers/{}/{}.pdf'.format(working_paper_code, working_paper_code)

    all_papers_df.loc[row, 'page_url'] = page_url
    all_papers_df.loc[row, 'pdf_url'] = pdf_url


    previously_collected_status, observation =  check_for_previous_collection(page_url, all_papers_df, row)
    if previously_collected_status:
        print('THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE')
        all_papers_df.loc[row, 'abstract'] = observation.abstract
        all_papers_df.loc[row, 'disclosures'] = observation.disclosures
        all_papers_df.loc[row, 'doi'] = observation.doi
        all_papers_df.loc[row, 'issue_date'] = observation.issue_date
        all_papers_df.loc[row, 'abstract'] = observation.abstract


    else:
        print('else')

        # 1. first collect info from the page
        
        try:
            random_proxy = generate_random_proxy_tunnel()
            page = requests.get(page_url, proxies=random_proxy)
        except:
            print('FAILED A REQUEST WHEN USING PROXY SERVER: {}'.format(random_proxy))

        bs_content = bs(page.content, 'html')

        abstract = bs_content.find('div', class_='page-header__intro-inner').text
        disclosure = bs_content.find('div', id='accordion-body-guid1').text
        citation_items = bs_content.find_all('div', class_='page-header__citation-item')
        for item in citation_items:
            if re.search(r'(?<=DOI )(.*)', item.text):
                doi = re.search(r'(?<=DOI )(.*)', item.text).group()

            elif re.search(r'(?<=Issue Date )(.*)', item.text): 
                issue_date = re.search(r'(?<=Issue Date )(.*)', item.text).group()

        all_papers_df.loc[row, 'abstract'] = abstract
        all_papers_df.loc[row, 'disclosures'] = disclosure
        all_papers_df.loc[row, 'doi'] = doi
        all_papers_df.loc[row, 'issue_date'] = issue_date

        # 2. Then download the page itself
        
        path_to_save = 'nber_working_papers/' + working_paper_code + '.pdf'
        with open(path_to_save, 'wb') as file:

            try:
                random_proxy = generate_random_proxy_tunnel()
                pdf = requests.get(pdf_url, proxies=random_proxy)
                file.write(pdf.content)
            except:
                print('FAILED A REQUEST WHEN USING PROXY SERVER: {}'.format(random_proxy))
    if row % 100 == 0:
        all_papers_df.to_csv('all_papers_df_temp_backup.csv', index=False, encoding='utf-8')

all_papers_df.to_csv('nber_affiliated_scholar_paper.csv', index=False, encoding='utf-8')
# Out:
# 0
# HAVE YET TO DO DOWNLOAD FOR ROW 0
# /papers/w24403
# else
# 1
# HAVE YET TO DO DOWNLOAD FOR ROW 1
# /papers/w24003
# else
# 2
# HAVE YET TO DO DOWNLOAD FOR ROW 2
# /papers/w20325
# else
# 3
# HAVE YET TO DO DOWNLOAD FOR ROW 3
# /papers/w19742
# else
# 4
# HAVE YET TO DO DOWNLOAD FOR ROW 4
# /papers/w17442
# else
# 5
# HAVE YET TO DO DOWNLOAD FOR ROW 5
# /papers/w15301
# else
# 6
# HAVE YET TO DO DOWNLOAD FOR ROW 6
# /papers/w14756
# else
# 7
# HAVE YET TO DO DOWNLOAD FOR ROW 7
# /papers/t0335
# else
# 8
# HAVE YET TO DO DOWNLOAD FOR ROW 8
# /papers/w12831
# else
# 9
# HAVE YET TO DO DOWNLOAD FOR ROW 9
# /papers/w12678
# else
# 10
# HAVE YET TO DO DOWNLOAD FOR ROW 10
# /papers/t0325
# else
# 11
# HAVE YET TO DO DOWNLOAD FOR ROW 11
# /papers/w10859
# else
# 12
# HAVE YET TO DO DOWNLOAD FOR ROW 12
# /papers/w10604
# else
# 13
# HAVE YET TO DO DOWNLOAD FOR ROW 13
# /papers/t0283
# else
# 14
# HAVE YET TO DO DOWNLOAD FOR ROW 14
# /papers/w8478
# else
# 15
# HAVE YET TO DO DOWNLOAD FOR ROW 15
# /papers/t0260
# else
# 16
# HAVE YET TO DO DOWNLOAD FOR ROW 16
# /papers/t0261
# else
# 17
# HAVE YET TO DO DOWNLOAD FOR ROW 17
# /papers/t0229
# else
# 18
# HAVE YET TO DO DOWNLOAD FOR ROW 18
# /papers/w29737
# else
# 19
# HAVE YET TO DO DOWNLOAD FOR ROW 19
# /papers/w23224
# else
# 20
# HAVE YET TO DO DOWNLOAD FOR ROW 20
# /papers/w20472
# else
# 21
# HAVE YET TO DO DOWNLOAD FOR ROW 21
# /papers/w15546
# else
# 22
# HAVE YET TO DO DOWNLOAD FOR ROW 22
# /papers/w13043
# else
# 23
# HAVE YET TO DO DOWNLOAD FOR ROW 23
# /papers/w7124
# else
# 24
# HAVE YET TO DO DOWNLOAD FOR ROW 24
# /papers/w6996
# else
# 25
# HAVE YET TO DO DOWNLOAD FOR ROW 25
# /papers/t0214
# else
# 26
# HAVE YET TO DO DOWNLOAD FOR ROW 26
# /papers/w6109
# else
# 27
# HAVE YET TO DO DOWNLOAD FOR ROW 27
# /papers/w6111
# else
# 28
# HAVE YET TO DO DOWNLOAD FOR ROW 28
# /papers/w6110
# else
# 29
# HAVE YET TO DO DOWNLOAD FOR ROW 29
# /papers/w5551
# else
# 30
# HAVE YET TO DO DOWNLOAD FOR ROW 30
# /papers/w5493
# else
# 31
# HAVE YET TO DO DOWNLOAD FOR ROW 31
# /papers/t0180
# else
# 32
# HAVE YET TO DO DOWNLOAD FOR ROW 32
# /papers/w5077
# else
# 33
# HAVE YET TO DO DOWNLOAD FOR ROW 33
# /papers/w4917
# else
# 34
# HAVE YET TO DO DOWNLOAD FOR ROW 34
# /papers/w4044
# else
# 35
# HAVE YET TO DO DOWNLOAD FOR ROW 35
# /papers/w3808
# else
# 36
# HAVE YET TO DO DOWNLOAD FOR ROW 36
# /papers/w3352
# else
# 37
# HAVE YET TO DO DOWNLOAD FOR ROW 37
# /papers/w3351
# else
# 38
# HAVE YET TO DO DOWNLOAD FOR ROW 38
# /papers/w3353
# else
# 39
# HAVE YET TO DO DOWNLOAD FOR ROW 39
# /papers/w3321
# else
# 40
# HAVE YET TO DO DOWNLOAD FOR ROW 40
# /papers/w3148
# else
# 41
# HAVE YET TO DO DOWNLOAD FOR ROW 41
# /papers/w3149
# else
# 42
# HAVE YET TO DO DOWNLOAD FOR ROW 42
# /papers/w2595
# else
# 43
# HAVE YET TO DO DOWNLOAD FOR ROW 43
# /papers/w2137
# else
# 44
# HAVE YET TO DO DOWNLOAD FOR ROW 44
# /papers/w1832
# else
# 45
# HAVE YET TO DO DOWNLOAD FOR ROW 45
# /papers/w1831
# else
# 46
# HAVE YET TO DO DOWNLOAD FOR ROW 46
# /papers/w26612
# else
# 47
# HAVE YET TO DO DOWNLOAD FOR ROW 47
# /papers/w24950
# else
# 48
# HAVE YET TO DO DOWNLOAD FOR ROW 48
# /papers/w24880
# else
# 49
# HAVE YET TO DO DOWNLOAD FOR ROW 49
# /papers/w24804
# else
# 50
# HAVE YET TO DO DOWNLOAD FOR ROW 50
# /papers/w24484
# else
# 51
# HAVE YET TO DO DOWNLOAD FOR ROW 51
# /papers/w24333
# else
# 52
# HAVE YET TO DO DOWNLOAD FOR ROW 52
# /papers/w22665
# else
# 53
# HAVE YET TO DO DOWNLOAD FOR ROW 53
# /papers/w14805
# else
# 54
# HAVE YET TO DO DOWNLOAD FOR ROW 54
# /papers/w14076
# else
# 55
# HAVE YET TO DO DOWNLOAD FOR ROW 55
# /papers/t0328
# else
# 56
# HAVE YET TO DO DOWNLOAD FOR ROW 56
# /papers/w10112
# else
# 57
# HAVE YET TO DO DOWNLOAD FOR ROW 57
# /papers/w8513
# else
# 58
# HAVE YET TO DO DOWNLOAD FOR ROW 58
# /papers/w4541
# else
# 59
# HAVE YET TO DO DOWNLOAD FOR ROW 59
# /papers/w4548
# else
# 60
# HAVE YET TO DO DOWNLOAD FOR ROW 60
# /papers/w4468
# else
# 61
# HAVE YET TO DO DOWNLOAD FOR ROW 61
# /papers/w4390
# else
# 62
# HAVE YET TO DO DOWNLOAD FOR ROW 62
# /papers/w3155
# else
# 63
# HAVE YET TO DO DOWNLOAD FOR ROW 63
# /papers/w2617
# else
# 64
# HAVE YET TO DO DOWNLOAD FOR ROW 64
# /papers/w2368
# else
# 65
# HAVE YET TO DO DOWNLOAD FOR ROW 65
# /papers/w1819
# else
# 66
# HAVE YET TO DO DOWNLOAD FOR ROW 66
# /papers/w1410
# else
# 67
# HAVE YET TO DO DOWNLOAD FOR ROW 67
# /papers/w1191
# else
# 68
# HAVE YET TO DO DOWNLOAD FOR ROW 68
# /papers/w1085
# else
# 69
# HAVE YET TO DO DOWNLOAD FOR ROW 69
# /papers/w1086
# else
# 70
# HAVE YET TO DO DOWNLOAD FOR ROW 70
# /papers/w0781
# else
# 71
# HAVE YET TO DO DOWNLOAD FOR ROW 71
# /papers/w0634
# else
# 72
# HAVE YET TO DO DOWNLOAD FOR ROW 72
# /papers/w0618
# else
# 73
# HAVE YET TO DO DOWNLOAD FOR ROW 73
# /papers/w0278
# else
# 74
# HAVE YET TO DO DOWNLOAD FOR ROW 74
# /papers/w0363
# else
# 75
# HAVE YET TO DO DOWNLOAD FOR ROW 75
# /papers/w29874
# else
# 76
# HAVE YET TO DO DOWNLOAD FOR ROW 76
# /papers/w29247
# else
# 77
# HAVE YET TO DO DOWNLOAD FOR ROW 77
# /papers/w29167
# else
# 78
# HAVE YET TO DO DOWNLOAD FOR ROW 78
# /papers/w29125
# else
# 79
# HAVE YET TO DO DOWNLOAD FOR ROW 79
# /papers/w29095
# else
# 80
# HAVE YET TO DO DOWNLOAD FOR ROW 80
# /papers/w29007
# else
# 81
# HAVE YET TO DO DOWNLOAD FOR ROW 81
# /papers/w28992
# else
# 82
# HAVE YET TO DO DOWNLOAD FOR ROW 82
# /papers/w28920
# else
# 83
# HAVE YET TO DO DOWNLOAD FOR ROW 83
# /papers/w28884
# else
# 84
# HAVE YET TO DO DOWNLOAD FOR ROW 84
# /papers/w28832
# else
# 85
# HAVE YET TO DO DOWNLOAD FOR ROW 85
# /papers/w28257
# else
# 86
# HAVE YET TO DO DOWNLOAD FOR ROW 86
# /papers/w27854
# else
# 87
# HAVE YET TO DO DOWNLOAD FOR ROW 87
# /papers/w27852
# else
# 88
# HAVE YET TO DO DOWNLOAD FOR ROW 88
# /papers/w27565
# else
# 89
# HAVE YET TO DO DOWNLOAD FOR ROW 89
# /papers/w27483
# else
# 90
# HAVE YET TO DO DOWNLOAD FOR ROW 90
# /papers/w27149
# else
# 91
# HAVE YET TO DO DOWNLOAD FOR ROW 91
# /papers/w27102
# else
# 92
# HAVE YET TO DO DOWNLOAD FOR ROW 92
# /papers/w27052
# else
# 93
# HAVE YET TO DO DOWNLOAD FOR ROW 93
# /papers/w26738
# else
# 94
# HAVE YET TO DO DOWNLOAD FOR ROW 94
# /papers/w26681
# else
# 95
# HAVE YET TO DO DOWNLOAD FOR ROW 95
# /papers/w26296
# else
# 96
# HAVE YET TO DO DOWNLOAD FOR ROW 96
# /papers/w25682
# else
# 97
# HAVE YET TO DO DOWNLOAD FOR ROW 97
# /papers/w25684
# else
# 98
# HAVE YET TO DO DOWNLOAD FOR ROW 98
# /papers/w25363
# else
# 99
# HAVE YET TO DO DOWNLOAD FOR ROW 99
# /papers/w24681
# else
# 100
# HAVE YET TO DO DOWNLOAD FOR ROW 100
# /papers/w24611
# else
# 101
# HAVE YET TO DO DOWNLOAD FOR ROW 101
# /papers/w24411
# else
# 102
# HAVE YET TO DO DOWNLOAD FOR ROW 102
# /papers/w24421
# else
# 103
# HAVE YET TO DO DOWNLOAD FOR ROW 103
# /papers/w24321
# else
# 104
# HAVE YET TO DO DOWNLOAD FOR ROW 104
# /papers/w24196
# else
# 105
# HAVE YET TO DO DOWNLOAD FOR ROW 105
# /papers/w24115
# else
# 106
# HAVE YET TO DO DOWNLOAD FOR ROW 106
# /papers/w24116
# else
# 107
# HAVE YET TO DO DOWNLOAD FOR ROW 107
# /papers/w24119
# else
# 108
# HAVE YET TO DO DOWNLOAD FOR ROW 108
# /papers/w24046
# else
# 109
# HAVE YET TO DO DOWNLOAD FOR ROW 109
# /papers/w23657
# else
# 110
# HAVE YET TO DO DOWNLOAD FOR ROW 110
# /papers/w23322
# else
# 111
# HAVE YET TO DO DOWNLOAD FOR ROW 111
# /papers/w23285
# else
# 112
# HAVE YET TO DO DOWNLOAD FOR ROW 112
# /papers/w23077
# else
# 113
# HAVE YET TO DO DOWNLOAD FOR ROW 113
# /papers/w22783
# else
# 114
# HAVE YET TO DO DOWNLOAD FOR ROW 114
# /papers/w22617
# else
# 115
# HAVE YET TO DO DOWNLOAD FOR ROW 115
# /papers/w22250
# else
# 116
# HAVE YET TO DO DOWNLOAD FOR ROW 116
# /papers/w22252
# else
# 117
# HAVE YET TO DO DOWNLOAD FOR ROW 117
# /papers/w22174
# else
# 118
# HAVE YET TO DO DOWNLOAD FOR ROW 118
# /papers/w21932
# else
# 119
# HAVE YET TO DO DOWNLOAD FOR ROW 119
# /papers/w21608
# else
# 120
# HAVE YET TO DO DOWNLOAD FOR ROW 120
# /papers/w21457
# else
# 121
# HAVE YET TO DO DOWNLOAD FOR ROW 121
# /papers/w21344
# else
# 122
# HAVE YET TO DO DOWNLOAD FOR ROW 122
# /papers/w20931
# else
# 123
# HAVE YET TO DO DOWNLOAD FOR ROW 123
# /papers/w20865
# else
# 124
# HAVE YET TO DO DOWNLOAD FOR ROW 124
# /papers/w20766
# else
# 125
# HAVE YET TO DO DOWNLOAD FOR ROW 125
# /papers/w20743
# else
# 126
# HAVE YET TO DO DOWNLOAD FOR ROW 126
# /papers/w20665
# else
# 127
# HAVE YET TO DO DOWNLOAD FOR ROW 127
# /papers/w20395
# else
# 128
# HAVE YET TO DO DOWNLOAD FOR ROW 128
# /papers/w20369
# else
# 129
# HAVE YET TO DO DOWNLOAD FOR ROW 129
# /papers/w20092
# else
# 130
# HAVE YET TO DO DOWNLOAD FOR ROW 130
# /papers/w20064
# else
# 131
# HAVE YET TO DO DOWNLOAD FOR ROW 131
# /papers/w20060
# else
# 132
# HAVE YET TO DO DOWNLOAD FOR ROW 132
# /papers/w20004
# else
# 133
# HAVE YET TO DO DOWNLOAD FOR ROW 133
# /papers/w19933
# else
# 134
# HAVE YET TO DO DOWNLOAD FOR ROW 134
# /papers/w19894
# else
# 135
# HAVE YET TO DO DOWNLOAD FOR ROW 135
# /papers/w19852
# else
# 136
# HAVE YET TO DO DOWNLOAD FOR ROW 136
# /papers/w19851
# else
# 137
# HAVE YET TO DO DOWNLOAD FOR ROW 137
# /papers/w19837
# else
# 138
# HAVE YET TO DO DOWNLOAD FOR ROW 138
# /papers/w19813
# else
# 139
# HAVE YET TO DO DOWNLOAD FOR ROW 139
# /papers/w19746
# else
# 140
# HAVE YET TO DO DOWNLOAD FOR ROW 140
# /papers/w19701
# else
# 141
# HAVE YET TO DO DOWNLOAD FOR ROW 141
# /papers/w19230
# else
# 142
# HAVE YET TO DO DOWNLOAD FOR ROW 142
# /papers/w19174
# else
# 143
# HAVE YET TO DO DOWNLOAD FOR ROW 143
# /papers/w19158
# else
# 144
# HAVE YET TO DO DOWNLOAD FOR ROW 144
# /papers/w18993
# else
# 145
# HAVE YET TO DO DOWNLOAD FOR ROW 145
# /papers/w18921
# else
# 146
# HAVE YET TO DO DOWNLOAD FOR ROW 146
# /papers/w18727
# else
# 147
# HAVE YET TO DO DOWNLOAD FOR ROW 147
# /papers/w18691
# else
# 148
# HAVE YET TO DO DOWNLOAD FOR ROW 148
# /papers/w18595
# else
# 149
# HAVE YET TO DO DOWNLOAD FOR ROW 149
# /papers/w18441
# else
# 150
# HAVE YET TO DO DOWNLOAD FOR ROW 150
# /papers/w18257
# else
# 151
# HAVE YET TO DO DOWNLOAD FOR ROW 151
# /papers/w18178
# else
# 152
# HAVE YET TO DO DOWNLOAD FOR ROW 152
# /papers/w18177
# else
# 153
# HAVE YET TO DO DOWNLOAD FOR ROW 153
# /papers/w17994
# else
# 154
# HAVE YET TO DO DOWNLOAD FOR ROW 154
# /papers/w17820
# else
# 155
# HAVE YET TO DO DOWNLOAD FOR ROW 155
# /papers/w17306
# else
# 156
# HAVE YET TO DO DOWNLOAD FOR ROW 156
# /papers/w17293
# else
# 157
# HAVE YET TO DO DOWNLOAD FOR ROW 157
# /papers/w17066
# else
# 158
# HAVE YET TO DO DOWNLOAD FOR ROW 158
# /papers/w16984
# else
# 159
# HAVE YET TO DO DOWNLOAD FOR ROW 159
# /papers/w16966
# else
# 160
# HAVE YET TO DO DOWNLOAD FOR ROW 160
# /papers/w16682
# else
# 161
# HAVE YET TO DO DOWNLOAD FOR ROW 161
# /papers/w16516
# else
# 162
# HAVE YET TO DO DOWNLOAD FOR ROW 162
# /papers/w16410
# else
# 163
# HAVE YET TO DO DOWNLOAD FOR ROW 163
# /papers/w16411
# else
# 164
# HAVE YET TO DO DOWNLOAD FOR ROW 164
# /papers/w16082
# else
# 165
# HAVE YET TO DO DOWNLOAD FOR ROW 165
# /papers/w16083
# else
# 166
# HAVE YET TO DO DOWNLOAD FOR ROW 166
# /papers/w15944
# else
# 167
# HAVE YET TO DO DOWNLOAD FOR ROW 167
# /papers/w15958
# else
# 168
# HAVE YET TO DO DOWNLOAD FOR ROW 168
# /papers/w15693
# else
# 169
# HAVE YET TO DO DOWNLOAD FOR ROW 169
# /papers/w15694
# else
# 170
# HAVE YET TO DO DOWNLOAD FOR ROW 170
# /papers/w15581
# else
# 171
# HAVE YET TO DO DOWNLOAD FOR ROW 171
# /papers/w15578
# else
# 172
# HAVE YET TO DO DOWNLOAD FOR ROW 172
# /papers/w15451
# else
# 173
# HAVE YET TO DO DOWNLOAD FOR ROW 173
# /papers/w15400
# else
# 174
# HAVE YET TO DO DOWNLOAD FOR ROW 174
# /papers/w15378
# else
# 175
# HAVE YET TO DO DOWNLOAD FOR ROW 175
# /papers/w15302
# else
# 176
# HAVE YET TO DO DOWNLOAD FOR ROW 176
# /papers/w15230
# else
# 177
# HAVE YET TO DO DOWNLOAD FOR ROW 177
# /papers/w15155
# else
# 178
# HAVE YET TO DO DOWNLOAD FOR ROW 178
# /papers/w14831
# else
# 179
# HAVE YET TO DO DOWNLOAD FOR ROW 179
# /papers/w14809
# else
# 180
# HAVE YET TO DO DOWNLOAD FOR ROW 180
# /papers/w14744
# else
# 181
# HAVE YET TO DO DOWNLOAD FOR ROW 181
# /papers/w14408
# else
# 182
# HAVE YET TO DO DOWNLOAD FOR ROW 182
# /papers/w14239
# else
# 183
# HAVE YET TO DO DOWNLOAD FOR ROW 183
# /papers/w14040
# else
# 184
# HAVE YET TO DO DOWNLOAD FOR ROW 184
# /papers/w14033
# else
# 185
# HAVE YET TO DO DOWNLOAD FOR ROW 185
# /papers/w13915
# else
# 186
# HAVE YET TO DO DOWNLOAD FOR ROW 186
# /papers/w13334
# else
# 187
# HAVE YET TO DO DOWNLOAD FOR ROW 187
# /papers/w13208
# else
# 188
# HAVE YET TO DO DOWNLOAD FOR ROW 188
# /papers/w12804
# else
# 189
# HAVE YET TO DO DOWNLOAD FOR ROW 189
# /papers/w12775
# else
# 190
# HAVE YET TO DO DOWNLOAD FOR ROW 190
# /papers/w12748
# else
# 191
# HAVE YET TO DO DOWNLOAD FOR ROW 191
# /papers/w12749
# else
# 192
# HAVE YET TO DO DOWNLOAD FOR ROW 192
# /papers/w12648
# else
# 193
# HAVE YET TO DO DOWNLOAD FOR ROW 193
# /papers/w12475
# else
# 194
# HAVE YET TO DO DOWNLOAD FOR ROW 194
# /papers/w12269
# else
# 195
# HAVE YET TO DO DOWNLOAD FOR ROW 195
# /papers/w12254
# else
# 196
# HAVE YET TO DO DOWNLOAD FOR ROW 196
# /papers/w12224
# else
# 197
# HAVE YET TO DO DOWNLOAD FOR ROW 197
# /papers/w12206
# else
# 198
# HAVE YET TO DO DOWNLOAD FOR ROW 198
# /papers/w12108
# else
# 199
# HAVE YET TO DO DOWNLOAD FOR ROW 199
# /papers/w11940
# else
# 200
# HAVE YET TO DO DOWNLOAD FOR ROW 200
# /papers/w11949
# else
# 201
# HAVE YET TO DO DOWNLOAD FOR ROW 201
# /papers/w11845
# else
# 202
# HAVE YET TO DO DOWNLOAD FOR ROW 202
# /papers/w11424
# else
# 203
# HAVE YET TO DO DOWNLOAD FOR ROW 203
# /papers/w11356
# else
# 204
# HAVE YET TO DO DOWNLOAD FOR ROW 204
# /papers/w11275
# else
# 205
# HAVE YET TO DO DOWNLOAD FOR ROW 205
# /papers/w11235
# else
# 206
# HAVE YET TO DO DOWNLOAD FOR ROW 206
# /papers/w11204
# else
# 207
# HAVE YET TO DO DOWNLOAD FOR ROW 207
# /papers/w11201
# else
# 208
# HAVE YET TO DO DOWNLOAD FOR ROW 208
# /papers/w11205
# else
# 209
# HAVE YET TO DO DOWNLOAD FOR ROW 209
# /papers/w10997
# else
# 210
# HAVE YET TO DO DOWNLOAD FOR ROW 210
# /papers/w10481
# else
# 211
# HAVE YET TO DO DOWNLOAD FOR ROW 211
# /papers/w10136
# else
# 212
# HAVE YET TO DO DOWNLOAD FOR ROW 212
# /papers/w10037
# else
# 213
# HAVE YET TO DO DOWNLOAD FOR ROW 213
# /papers/w10038
# else
# 214
# HAVE YET TO DO DOWNLOAD FOR ROW 214
# /papers/w9934
# else
# 215
# HAVE YET TO DO DOWNLOAD FOR ROW 215
# /papers/w9802
# else
# 216
# HAVE YET TO DO DOWNLOAD FOR ROW 216
# /papers/w9377
# else
# 217
# HAVE YET TO DO DOWNLOAD FOR ROW 217
# /papers/w9378
# else
# 218
# HAVE YET TO DO DOWNLOAD FOR ROW 218
# /papers/w9191
# else
# 219
# HAVE YET TO DO DOWNLOAD FOR ROW 219
# /papers/w9124
# else
# 220
# HAVE YET TO DO DOWNLOAD FOR ROW 220
# /papers/w9066
# else
# 221
# HAVE YET TO DO DOWNLOAD FOR ROW 221
# /papers/w9013
# else
# 222
# HAVE YET TO DO DOWNLOAD FOR ROW 222
# /papers/w8831
# else
# 223
# HAVE YET TO DO DOWNLOAD FOR ROW 223
# /papers/w8832
# else
# 224
# HAVE YET TO DO DOWNLOAD FOR ROW 224
# /papers/w8460
# else
# 225
# HAVE YET TO DO DOWNLOAD FOR ROW 225
# /papers/w8287
# else
# 226
# HAVE YET TO DO DOWNLOAD FOR ROW 226
# /papers/w8083
# else
# 227
# HAVE YET TO DO DOWNLOAD FOR ROW 227
# /papers/w7938
# else
# 228
# HAVE YET TO DO DOWNLOAD FOR ROW 228
# /papers/w7986
# else
# 229
# HAVE YET TO DO DOWNLOAD FOR ROW 229
# /papers/w7800
# else
# 230
# HAVE YET TO DO DOWNLOAD FOR ROW 230
# /papers/w7771
# else
# 231
# HAVE YET TO DO DOWNLOAD FOR ROW 231
# /papers/w7544
# else
# 232
# HAVE YET TO DO DOWNLOAD FOR ROW 232
# /papers/w7444
# else
# 233
# HAVE YET TO DO DOWNLOAD FOR ROW 233
# /papers/w7352
# else
# 234
# HAVE YET TO DO DOWNLOAD FOR ROW 234
# /papers/w7184
# else
# 235
# HAVE YET TO DO DOWNLOAD FOR ROW 235
# /papers/w7018
# else
# 236
# HAVE YET TO DO DOWNLOAD FOR ROW 236
# /papers/w6879
# else
# 237
# HAVE YET TO DO DOWNLOAD FOR ROW 237
# /papers/w6740
# else
# 238
# HAVE YET TO DO DOWNLOAD FOR ROW 238
# /papers/w6686
# else
# 239
# HAVE YET TO DO DOWNLOAD FOR ROW 239
# /papers/w6658
# else
# 240
# HAVE YET TO DO DOWNLOAD FOR ROW 240
# /papers/w6670
# else
# 241
# HAVE YET TO DO DOWNLOAD FOR ROW 241
# /papers/w6357
# else
# 242
# HAVE YET TO DO DOWNLOAD FOR ROW 242
# /papers/w5605
# else
# 243
# HAVE YET TO DO DOWNLOAD FOR ROW 243
# /papers/w29460
# else
# 244
# HAVE YET TO DO DOWNLOAD FOR ROW 244
# /papers/w28600
# else
# 245
# HAVE YET TO DO DOWNLOAD FOR ROW 245
# /papers/w28153
# else
# 246
# HAVE YET TO DO DOWNLOAD FOR ROW 246
# /papers/w25116
# else
# 247
# HAVE YET TO DO DOWNLOAD FOR ROW 247
# /papers/w24579
# else
# 248
# HAVE YET TO DO DOWNLOAD FOR ROW 248
# /papers/w26030
# else
# 249
# HAVE YET TO DO DOWNLOAD FOR ROW 249
# /papers/w25639
# else
# 250
# HAVE YET TO DO DOWNLOAD FOR ROW 250
# /papers/w24770
# else
# 251
# HAVE YET TO DO DOWNLOAD FOR ROW 251
# /papers/w23733
# else
# 252
# HAVE YET TO DO DOWNLOAD FOR ROW 252
# /papers/w21562
# else
# 253
# HAVE YET TO DO DOWNLOAD FOR ROW 253
# /papers/w28400
# else
# 254
# HAVE YET TO DO DOWNLOAD FOR ROW 254
# /papers/w26959
# else
# 255
# HAVE YET TO DO DOWNLOAD FOR ROW 255
# /papers/w25167
# else
# 256
# HAVE YET TO DO DOWNLOAD FOR ROW 256
# /papers/w23029
# else
# 257
# HAVE YET TO DO DOWNLOAD FOR ROW 257
# /papers/w21655
# else
# 258
# HAVE YET TO DO DOWNLOAD FOR ROW 258
# /papers/w20781
# else
# 259
# HAVE YET TO DO DOWNLOAD FOR ROW 259
# /papers/w20531
# else
# 260
# HAVE YET TO DO DOWNLOAD FOR ROW 260
# /papers/w17985
# else
# 261
# HAVE YET TO DO DOWNLOAD FOR ROW 261
# /papers/w16579
# else
# 262
# HAVE YET TO DO DOWNLOAD FOR ROW 262
# /papers/w16508
# else
# 263
# HAVE YET TO DO DOWNLOAD FOR ROW 263
# /papers/w14743
# else
# 264
# HAVE YET TO DO DOWNLOAD FOR ROW 264
# /papers/w14161
# else
# 265
# HAVE YET TO DO DOWNLOAD FOR ROW 265
# /papers/w13883
# else
# 266
# HAVE YET TO DO DOWNLOAD FOR ROW 266
# /papers/w11693
# else
# 267
# HAVE YET TO DO DOWNLOAD FOR ROW 267
# /papers/w9811
# else
# 268
# HAVE YET TO DO DOWNLOAD FOR ROW 268
# /papers/w9358
# else
# 269
# HAVE YET TO DO DOWNLOAD FOR ROW 269
# /papers/w8473
# else
# 270
# HAVE YET TO DO DOWNLOAD FOR ROW 270
# /papers/t0267
# else
# 271
# HAVE YET TO DO DOWNLOAD FOR ROW 271
# /papers/w7831
# else
# 272
# HAVE YET TO DO DOWNLOAD FOR ROW 272
# /papers/w7236
# else
# 273
# HAVE YET TO DO DOWNLOAD FOR ROW 273
# /papers/w6279
# else
# 274
# HAVE YET TO DO DOWNLOAD FOR ROW 274
# /papers/w6010
# else
# 275
# HAVE YET TO DO DOWNLOAD FOR ROW 275
# /papers/w5522
# else
# 276
# HAVE YET TO DO DOWNLOAD FOR ROW 276
# /papers/w5438
# else
# 277
# HAVE YET TO DO DOWNLOAD FOR ROW 277
# /papers/w5378
# else
# 278
# HAVE YET TO DO DOWNLOAD FOR ROW 278
# /papers/w5072
# else
# 279
# HAVE YET TO DO DOWNLOAD FOR ROW 279
# /papers/w4950
# else
# 280
# HAVE YET TO DO DOWNLOAD FOR ROW 280
# /papers/t0156
# else
# 281
# HAVE YET TO DO DOWNLOAD FOR ROW 281
# /papers/w4142
# else
# 282
# HAVE YET TO DO DOWNLOAD FOR ROW 282
# /papers/w4133
# else
# 283
# HAVE YET TO DO DOWNLOAD FOR ROW 283
# /papers/w3834
# else
# 284
# HAVE YET TO DO DOWNLOAD FOR ROW 284
# /papers/w3724
# else
# 285
# HAVE YET TO DO DOWNLOAD FOR ROW 285
# /papers/w3714
# else
# 286
# HAVE YET TO DO DOWNLOAD FOR ROW 286
# /papers/w3474
# else
# 287
# HAVE YET TO DO DOWNLOAD FOR ROW 287
# /papers/w3123
# else
# 288
# HAVE YET TO DO DOWNLOAD FOR ROW 288
# /papers/w3046
# else
# 289
# HAVE YET TO DO DOWNLOAD FOR ROW 289
# /papers/w2155
# else
# 290
# HAVE YET TO DO DOWNLOAD FOR ROW 290
# /papers/w2121
# else
# 291
# HAVE YET TO DO DOWNLOAD FOR ROW 291
# /papers/w2012
# else
# 292
# HAVE YET TO DO DOWNLOAD FOR ROW 292
# /papers/w1895
# else
# 293
# HAVE YET TO DO DOWNLOAD FOR ROW 293
# /papers/w1816
# else
# 294
# HAVE YET TO DO DOWNLOAD FOR ROW 294
# /papers/w1616
# else
# 295
# HAVE YET TO DO DOWNLOAD FOR ROW 295
# /papers/w16873
# else
# 296
# HAVE YET TO DO DOWNLOAD FOR ROW 296
# /papers/w16673
# else
# 297
# HAVE YET TO DO DOWNLOAD FOR ROW 297
# /papers/w13479
# else
# 298
# HAVE YET TO DO DOWNLOAD FOR ROW 298
# /papers/w11177
# else
# 299
# HAVE YET TO DO DOWNLOAD FOR ROW 299
# /papers/w10043
# else
# 300
# HAVE YET TO DO DOWNLOAD FOR ROW 300
# /papers/w8770
# else
# 301
# HAVE YET TO DO DOWNLOAD FOR ROW 301
# /papers/w7058
# else
# 302
# HAVE YET TO DO DOWNLOAD FOR ROW 302
# /papers/w6808
# else
# 303
# HAVE YET TO DO DOWNLOAD FOR ROW 303
# /papers/w6208
# else
# 304
# HAVE YET TO DO DOWNLOAD FOR ROW 304
# /papers/w5201
# else
# 305
# HAVE YET TO DO DOWNLOAD FOR ROW 305
# /papers/w5001
# else
# 306
# HAVE YET TO DO DOWNLOAD FOR ROW 306
# /papers/w4960
# else
# 307
# HAVE YET TO DO DOWNLOAD FOR ROW 307
# /papers/w4787
# else
# 308
# HAVE YET TO DO DOWNLOAD FOR ROW 308
# /papers/w26824
# else
# 309
# HAVE YET TO DO DOWNLOAD FOR ROW 309
# /papers/w26631
# else
# 310
# HAVE YET TO DO DOWNLOAD FOR ROW 310
# /papers/w26374
# else
# 311
# HAVE YET TO DO DOWNLOAD FOR ROW 311
# /papers/w25456
# else
# 312
# HAVE YET TO DO DOWNLOAD FOR ROW 312
# /papers/w25217
# else
# 313
# HAVE YET TO DO DOWNLOAD FOR ROW 313
# /papers/w23826
# else
# 314
# HAVE YET TO DO DOWNLOAD FOR ROW 314
# /papers/w23298
# else
# 315
# HAVE YET TO DO DOWNLOAD FOR ROW 315
# /papers/w20673
# else
# 316
# HAVE YET TO DO DOWNLOAD FOR ROW 316
# /papers/w23575
# else
# 317
# HAVE YET TO DO DOWNLOAD FOR ROW 317
# /papers/w23442
# else
# 318
# HAVE YET TO DO DOWNLOAD FOR ROW 318
# /papers/w22901
# else
# 319
# HAVE YET TO DO DOWNLOAD FOR ROW 319
# /papers/w22260
# else
# 320
# HAVE YET TO DO DOWNLOAD FOR ROW 320
# /papers/w19935
# else
# 321
# HAVE YET TO DO DOWNLOAD FOR ROW 321
# /papers/w18598
# else
# 322
# HAVE YET TO DO DOWNLOAD FOR ROW 322
# /papers/w18064
# else
# 323
# HAVE YET TO DO DOWNLOAD FOR ROW 323
# /papers/w18068
# else
# 324
# HAVE YET TO DO DOWNLOAD FOR ROW 324
# /papers/w29726
# else
# 325
# HAVE YET TO DO DOWNLOAD FOR ROW 325
# /papers/w29608
# else
# 326
# HAVE YET TO DO DOWNLOAD FOR ROW 326
# /papers/w29417
# else
# 327
# HAVE YET TO DO DOWNLOAD FOR ROW 327
# /papers/w28241
# else
# 328
# HAVE YET TO DO DOWNLOAD FOR ROW 328
# /papers/w27834
# else
# 329
# HAVE YET TO DO DOWNLOAD FOR ROW 329
# /papers/w26584
# else
# 330
# HAVE YET TO DO DOWNLOAD FOR ROW 330
# /papers/w26137
# else
# 331
# HAVE YET TO DO DOWNLOAD FOR ROW 331
# /papers/w24172
# else
# 332
# HAVE YET TO DO DOWNLOAD FOR ROW 332
# /papers/w23891
# else
# 333
# HAVE YET TO DO DOWNLOAD FOR ROW 333
# /papers/w23698
# else
# 334
# HAVE YET TO DO DOWNLOAD FOR ROW 334
# /papers/w23486
# else
# 335
# HAVE YET TO DO DOWNLOAD FOR ROW 335
# /papers/w23144
# else
# 336
# HAVE YET TO DO DOWNLOAD FOR ROW 336
# /papers/w23015
# else
# 337
# HAVE YET TO DO DOWNLOAD FOR ROW 337
# /papers/w21748
# else
# 338
# HAVE YET TO DO DOWNLOAD FOR ROW 338
# /papers/w21705
# else
# 339
# HAVE YET TO DO DOWNLOAD FOR ROW 339
# /papers/w20800
# else
# 340
# HAVE YET TO DO DOWNLOAD FOR ROW 340
# /papers/w20792
# else
# 341
# HAVE YET TO DO DOWNLOAD FOR ROW 341
# /papers/w20173
# else
# 342
# HAVE YET TO DO DOWNLOAD FOR ROW 342
# /papers/w19774
# else
# 343
# HAVE YET TO DO DOWNLOAD FOR ROW 343
# /papers/w19355
# else
# 344
# HAVE YET TO DO DOWNLOAD FOR ROW 344
# /papers/w19275
# else
# 345
# HAVE YET TO DO DOWNLOAD FOR ROW 345
# /papers/w18662
# else
# 346
# HAVE YET TO DO DOWNLOAD FOR ROW 346
# /papers/w17332
# else
# 347
# HAVE YET TO DO DOWNLOAD FOR ROW 347
# /papers/w17264
# else
# 348
# HAVE YET TO DO DOWNLOAD FOR ROW 348
# /papers/w16643
# else
# 349
# HAVE YET TO DO DOWNLOAD FOR ROW 349
# /papers/w16566
# else
# 350
# HAVE YET TO DO DOWNLOAD FOR ROW 350
# /papers/w15794
# else
# 351
# HAVE YET TO DO DOWNLOAD FOR ROW 351
# /papers/w15740
# else
# 352
# HAVE YET TO DO DOWNLOAD FOR ROW 352
# /papers/w15549
# else
# 353
# HAVE YET TO DO DOWNLOAD FOR ROW 353
# /papers/w14781
# else
# 354
# HAVE YET TO DO DOWNLOAD FOR ROW 354
# /papers/w13411
# else
# 355
# HAVE YET TO DO DOWNLOAD FOR ROW 355
# /papers/w12790
# else
# 356
# HAVE YET TO DO DOWNLOAD FOR ROW 356
# /papers/w12005
# else
# 357
# HAVE YET TO DO DOWNLOAD FOR ROW 357
# /papers/w11835
# else
# 358
# HAVE YET TO DO DOWNLOAD FOR ROW 358
# /papers/t0314
# else
# 359
# HAVE YET TO DO DOWNLOAD FOR ROW 359
# /papers/w11219
# else
# 360
# HAVE YET TO DO DOWNLOAD FOR ROW 360
# /papers/w10975
# else
# 361
# HAVE YET TO DO DOWNLOAD FOR ROW 361
# /papers/w10713
# else
# 362
# HAVE YET TO DO DOWNLOAD FOR ROW 362
# /papers/w10428
# else
# 363
# HAVE YET TO DO DOWNLOAD FOR ROW 363
# /papers/w9708
# else
# 364
# HAVE YET TO DO DOWNLOAD FOR ROW 364
# /papers/w9545
# else
# 365
# HAVE YET TO DO DOWNLOAD FOR ROW 365
# /papers/w9389
# else
# 366
# HAVE YET TO DO DOWNLOAD FOR ROW 366
# /papers/w9263
# else
# 367
# HAVE YET TO DO DOWNLOAD FOR ROW 367
# /papers/w8660
# else
# 368
# HAVE YET TO DO DOWNLOAD FOR ROW 368
# /papers/w8456
# else
# 369
# HAVE YET TO DO DOWNLOAD FOR ROW 369
# /papers/w8343
# else
# 370
# HAVE YET TO DO DOWNLOAD FOR ROW 370
# /papers/w8042
# else
# 371
# HAVE YET TO DO DOWNLOAD FOR ROW 371
# /papers/t0248
# else
# 372
# HAVE YET TO DO DOWNLOAD FOR ROW 372
# /papers/w7444
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 373
# HAVE YET TO DO DOWNLOAD FOR ROW 373
# /papers/w7424
# else
# 374
# HAVE YET TO DO DOWNLOAD FOR ROW 374
# /papers/t0241
# else
# 375
# HAVE YET TO DO DOWNLOAD FOR ROW 375
# /papers/w6781
# else
# 376
# HAVE YET TO DO DOWNLOAD FOR ROW 376
# /papers/w6679
# else
# 377
# HAVE YET TO DO DOWNLOAD FOR ROW 377
# /papers/w6670
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 378
# HAVE YET TO DO DOWNLOAD FOR ROW 378
# /papers/t0229
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 379
# HAVE YET TO DO DOWNLOAD FOR ROW 379
# /papers/w5888
# else
# 380
# HAVE YET TO DO DOWNLOAD FOR ROW 380
# /papers/w5807
# else
# 381
# HAVE YET TO DO DOWNLOAD FOR ROW 381
# /papers/w5778
# else
# 382
# HAVE YET TO DO DOWNLOAD FOR ROW 382
# /papers/w5406
# else
# 383
# HAVE YET TO DO DOWNLOAD FOR ROW 383
# /papers/w5192
# else
# 384
# HAVE YET TO DO DOWNLOAD FOR ROW 384
# /papers/t0181
# else
# 385
# HAVE YET TO DO DOWNLOAD FOR ROW 385
# /papers/t0127
# else
# 386
# HAVE YET TO DO DOWNLOAD FOR ROW 386
# /papers/t0150
# else
# 387
# HAVE YET TO DO DOWNLOAD FOR ROW 387
# /papers/t0178
# else
# 388
# HAVE YET TO DO DOWNLOAD FOR ROW 388
# /papers/t0118
# else
# 389
# HAVE YET TO DO DOWNLOAD FOR ROW 389
# /papers/t0172
# else
# 390
# HAVE YET TO DO DOWNLOAD FOR ROW 390
# /papers/t0136
# else
# 391
# HAVE YET TO DO DOWNLOAD FOR ROW 391
# /papers/w4067
# else
# 392
# HAVE YET TO DO DOWNLOAD FOR ROW 392
# /papers/t0117
# else
# 393
# HAVE YET TO DO DOWNLOAD FOR ROW 393
# /papers/t0115
# else
# 394
# HAVE YET TO DO DOWNLOAD FOR ROW 394
# /papers/w3571
# else
# 395
# HAVE YET TO DO DOWNLOAD FOR ROW 395
# /papers/w3572
# else
# 396
# HAVE YET TO DO DOWNLOAD FOR ROW 396
# /papers/w3514
# else
# 397
# HAVE YET TO DO DOWNLOAD FOR ROW 397
# /papers/w3492
# else
# 398
# HAVE YET TO DO DOWNLOAD FOR ROW 398
# /papers/w3312
# else
# 399
# HAVE YET TO DO DOWNLOAD FOR ROW 399
# /papers/w2991
# else
# 400
# HAVE YET TO DO DOWNLOAD FOR ROW 400
# /papers/w29522
# else
# 401
# HAVE YET TO DO DOWNLOAD FOR ROW 401
# /papers/w28506
# else
# 402
# HAVE YET TO DO DOWNLOAD FOR ROW 402
# /papers/w24831
# else
# 403
# HAVE YET TO DO DOWNLOAD FOR ROW 403
# /papers/w19939
# else
# 404
# HAVE YET TO DO DOWNLOAD FOR ROW 404
# /papers/w19353
# else
# 405
# HAVE YET TO DO DOWNLOAD FOR ROW 405
# /papers/w18834
# else
# 406
# HAVE YET TO DO DOWNLOAD FOR ROW 406
# /papers/w18006
# else
# 407
# HAVE YET TO DO DOWNLOAD FOR ROW 407
# /papers/w17607
# else
# 408
# HAVE YET TO DO DOWNLOAD FOR ROW 408
# /papers/w17476
# else
# 409
# HAVE YET TO DO DOWNLOAD FOR ROW 409
# /papers/w16743
# else
# 410
# HAVE YET TO DO DOWNLOAD FOR ROW 410
# /papers/w16037
# else
# 411
# HAVE YET TO DO DOWNLOAD FOR ROW 411
# /papers/w15746
# else
# 412
# HAVE YET TO DO DOWNLOAD FOR ROW 412
# /papers/w14798
# else
# 413
# HAVE YET TO DO DOWNLOAD FOR ROW 413
# /papers/w13859
# else
# 414
# HAVE YET TO DO DOWNLOAD FOR ROW 414
# /papers/w13258
# else
# 415
# HAVE YET TO DO DOWNLOAD FOR ROW 415
# /papers/w12380
# else
# 416
# HAVE YET TO DO DOWNLOAD FOR ROW 416
# /papers/w11916
# else
# 417
# HAVE YET TO DO DOWNLOAD FOR ROW 417
# /papers/w11394
# else
# 418
# HAVE YET TO DO DOWNLOAD FOR ROW 418
# /papers/w11189
# else
# 419
# HAVE YET TO DO DOWNLOAD FOR ROW 419
# /papers/w10795
# else
# 420
# HAVE YET TO DO DOWNLOAD FOR ROW 420
# /papers/w10401
# else
# 421
# HAVE YET TO DO DOWNLOAD FOR ROW 421
# /papers/w9094
# else
# 422
# HAVE YET TO DO DOWNLOAD FOR ROW 422
# /papers/w8997
# else
# 423
# HAVE YET TO DO DOWNLOAD FOR ROW 423
# /papers/w8378
# else
# 424
# HAVE YET TO DO DOWNLOAD FOR ROW 424
# /papers/w7457
# else
# 425
# HAVE YET TO DO DOWNLOAD FOR ROW 425
# /papers/w7294
# else
# 426
# HAVE YET TO DO DOWNLOAD FOR ROW 426
# /papers/w6982
# else
# 427
# HAVE YET TO DO DOWNLOAD FOR ROW 427
# /papers/w6902
# else
# 428
# HAVE YET TO DO DOWNLOAD FOR ROW 428
# /papers/w6106
# else
# 429
# HAVE YET TO DO DOWNLOAD FOR ROW 429
# /papers/w5916
# else
# 430
# HAVE YET TO DO DOWNLOAD FOR ROW 430
# /papers/w4491
# else
# 431
# HAVE YET TO DO DOWNLOAD FOR ROW 431
# /papers/w4447
# else
# 432
# HAVE YET TO DO DOWNLOAD FOR ROW 432
# /papers/w4143
# else
# 433
# HAVE YET TO DO DOWNLOAD FOR ROW 433
# /papers/w4036
# else
# 434
# HAVE YET TO DO DOWNLOAD FOR ROW 434
# /papers/w3417
# else
# 435
# HAVE YET TO DO DOWNLOAD FOR ROW 435
# /papers/w1840
# else
# 436
# HAVE YET TO DO DOWNLOAD FOR ROW 436
# /papers/w1489
# else
# 437
# HAVE YET TO DO DOWNLOAD FOR ROW 437
# /papers/w1500
# else
# 438
# HAVE YET TO DO DOWNLOAD FOR ROW 438
# /papers/w1149
# else
# 439
# HAVE YET TO DO DOWNLOAD FOR ROW 439
# /papers/w0050
# else
# 440
# HAVE YET TO DO DOWNLOAD FOR ROW 440
# /papers/w29522
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 441
# HAVE YET TO DO DOWNLOAD FOR ROW 441
# /papers/w28506
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 442
# HAVE YET TO DO DOWNLOAD FOR ROW 442
# /papers/w24831
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 443
# HAVE YET TO DO DOWNLOAD FOR ROW 443
# /papers/w19939
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 444
# HAVE YET TO DO DOWNLOAD FOR ROW 444
# /papers/w19353
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 445
# HAVE YET TO DO DOWNLOAD FOR ROW 445
# /papers/w18834
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 446
# HAVE YET TO DO DOWNLOAD FOR ROW 446
# /papers/w18006
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 447
# HAVE YET TO DO DOWNLOAD FOR ROW 447
# /papers/w17607
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 448
# HAVE YET TO DO DOWNLOAD FOR ROW 448
# /papers/w17476
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 449
# HAVE YET TO DO DOWNLOAD FOR ROW 449
# /papers/w16743
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 450
# HAVE YET TO DO DOWNLOAD FOR ROW 450
# /papers/w16037
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 451
# HAVE YET TO DO DOWNLOAD FOR ROW 451
# /papers/w15746
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 452
# HAVE YET TO DO DOWNLOAD FOR ROW 452
# /papers/w14798
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 453
# HAVE YET TO DO DOWNLOAD FOR ROW 453
# /papers/w13859
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 454
# HAVE YET TO DO DOWNLOAD FOR ROW 454
# /papers/w13258
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 455
# HAVE YET TO DO DOWNLOAD FOR ROW 455
# /papers/w12380
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 456
# HAVE YET TO DO DOWNLOAD FOR ROW 456
# /papers/w11916
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 457
# HAVE YET TO DO DOWNLOAD FOR ROW 457
# /papers/w11394
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 458
# HAVE YET TO DO DOWNLOAD FOR ROW 458
# /papers/w11189
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 459
# HAVE YET TO DO DOWNLOAD FOR ROW 459
# /papers/w10795
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 460
# HAVE YET TO DO DOWNLOAD FOR ROW 460
# /papers/w10401
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 461
# HAVE YET TO DO DOWNLOAD FOR ROW 461
# /papers/w9094
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 462
# HAVE YET TO DO DOWNLOAD FOR ROW 462
# /papers/w8997
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 463
# HAVE YET TO DO DOWNLOAD FOR ROW 463
# /papers/w8378
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 464
# HAVE YET TO DO DOWNLOAD FOR ROW 464
# /papers/w7457
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 465
# HAVE YET TO DO DOWNLOAD FOR ROW 465
# /papers/w7294
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 466
# HAVE YET TO DO DOWNLOAD FOR ROW 466
# /papers/w6982
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 467
# HAVE YET TO DO DOWNLOAD FOR ROW 467
# /papers/w6902
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 468
# HAVE YET TO DO DOWNLOAD FOR ROW 468
# /papers/w6106
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 469
# HAVE YET TO DO DOWNLOAD FOR ROW 469
# /papers/w5916
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 470
# HAVE YET TO DO DOWNLOAD FOR ROW 470
# /papers/w4491
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 471
# HAVE YET TO DO DOWNLOAD FOR ROW 471
# /papers/w4447
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 472
# HAVE YET TO DO DOWNLOAD FOR ROW 472
# /papers/w4143
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 473
# HAVE YET TO DO DOWNLOAD FOR ROW 473
# /papers/w4036
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 474
# HAVE YET TO DO DOWNLOAD FOR ROW 474
# /papers/w3417
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 475
# HAVE YET TO DO DOWNLOAD FOR ROW 475
# /papers/w1840
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 476
# HAVE YET TO DO DOWNLOAD FOR ROW 476
# /papers/w1489
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 477
# HAVE YET TO DO DOWNLOAD FOR ROW 477
# /papers/w1500
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 478
# HAVE YET TO DO DOWNLOAD FOR ROW 478
# /papers/w1149
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 479
# HAVE YET TO DO DOWNLOAD FOR ROW 479
# /papers/w0050
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 480
# HAVE YET TO DO DOWNLOAD FOR ROW 480
# /papers/w29972
# else
# 481
# HAVE YET TO DO DOWNLOAD FOR ROW 481
# /papers/w29669
# else
# 482
# HAVE YET TO DO DOWNLOAD FOR ROW 482
# /papers/w29401
# else
# 483
# HAVE YET TO DO DOWNLOAD FOR ROW 483
# /papers/w28257
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 484
# HAVE YET TO DO DOWNLOAD FOR ROW 484
# /papers/w27834
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 485
# HAVE YET TO DO DOWNLOAD FOR ROW 485
# /papers/w27196
# else
# 486
# HAVE YET TO DO DOWNLOAD FOR ROW 486
# /papers/w26705
# else
# 487
# HAVE YET TO DO DOWNLOAD FOR ROW 487
# /papers/w25588
# else
# 488
# HAVE YET TO DO DOWNLOAD FOR ROW 488
# /papers/w24871
# else
# 489
# HAVE YET TO DO DOWNLOAD FOR ROW 489
# /papers/w23914
# else
# 490
# HAVE YET TO DO DOWNLOAD FOR ROW 490
# /papers/w23466
# else
# 491
# HAVE YET TO DO DOWNLOAD FOR ROW 491
# /papers/w23396
# else
# 492
# HAVE YET TO DO DOWNLOAD FOR ROW 492
# /papers/w23173
# else
# 493
# HAVE YET TO DO DOWNLOAD FOR ROW 493
# /papers/w23108
# else
# 494
# HAVE YET TO DO DOWNLOAD FOR ROW 494
# /papers/w23015
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 495
# HAVE YET TO DO DOWNLOAD FOR ROW 495
# /papers/w22879
# else
# 496
# HAVE YET TO DO DOWNLOAD FOR ROW 496
# /papers/w22637
# else
# 497
# HAVE YET TO DO DOWNLOAD FOR ROW 497
# /papers/w22267
# else
# 498
# HAVE YET TO DO DOWNLOAD FOR ROW 498
# /papers/w21908
# else
# 499
# HAVE YET TO DO DOWNLOAD FOR ROW 499
# /papers/w21906
# else
# 500
# HAVE YET TO DO DOWNLOAD FOR ROW 500
# /papers/w21144
# else
# 501
# HAVE YET TO DO DOWNLOAD FOR ROW 501
# /papers/w20840
# else
# 502
# HAVE YET TO DO DOWNLOAD FOR ROW 502
# /papers/w20800
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 503
# HAVE YET TO DO DOWNLOAD FOR ROW 503
# /papers/w20485
# else
# 504
# HAVE YET TO DO DOWNLOAD FOR ROW 504
# /papers/w20395
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 505
# HAVE YET TO DO DOWNLOAD FOR ROW 505
# /papers/w19837
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 506
# HAVE YET TO DO DOWNLOAD FOR ROW 506
# /papers/w19226
# else
# 507
# HAVE YET TO DO DOWNLOAD FOR ROW 507
# /papers/w18940
# else
# 508
# HAVE YET TO DO DOWNLOAD FOR ROW 508
# /papers/w18938
# else
# 509
# HAVE YET TO DO DOWNLOAD FOR ROW 509
# /papers/w18711
# else
# 510
# HAVE YET TO DO DOWNLOAD FOR ROW 510
# /papers/w18172
# else
# 511
# HAVE YET TO DO DOWNLOAD FOR ROW 511
# /papers/w18125
# else
# 512
# HAVE YET TO DO DOWNLOAD FOR ROW 512
# /papers/w18054
# else
# 513
# HAVE YET TO DO DOWNLOAD FOR ROW 513
# /papers/w17972
# else
# 514
# HAVE YET TO DO DOWNLOAD FOR ROW 514
# /papers/w17820
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 515
# HAVE YET TO DO DOWNLOAD FOR ROW 515
# /papers/w17697
# else
# 516
# HAVE YET TO DO DOWNLOAD FOR ROW 516
# /papers/w16533
# else
# 517
# HAVE YET TO DO DOWNLOAD FOR ROW 517
# /papers/w16082
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 518
# HAVE YET TO DO DOWNLOAD FOR ROW 518
# /papers/w15150
# else
# 519
# HAVE YET TO DO DOWNLOAD FOR ROW 519
# /papers/w15116
# else
# 520
# HAVE YET TO DO DOWNLOAD FOR ROW 520
# /papers/w14652
# else
# 521
# HAVE YET TO DO DOWNLOAD FOR ROW 521
# /papers/w14348
# else
# 522
# HAVE YET TO DO DOWNLOAD FOR ROW 522
# /papers/w12860
# else
# 523
# HAVE YET TO DO DOWNLOAD FOR ROW 523
# /papers/w12436
# else
# 524
# HAVE YET TO DO DOWNLOAD FOR ROW 524
# /papers/w11986
# else
# 525
# HAVE YET TO DO DOWNLOAD FOR ROW 525
# /papers/w11743
# else
# 526
# HAVE YET TO DO DOWNLOAD FOR ROW 526
# /papers/w11742
# else
# 527
# HAVE YET TO DO DOWNLOAD FOR ROW 527
# /papers/w11627
# else
# 528
# HAVE YET TO DO DOWNLOAD FOR ROW 528
# /papers/w11628
# else
# 529
# HAVE YET TO DO DOWNLOAD FOR ROW 529
# /papers/w10763
# else
# 530
# HAVE YET TO DO DOWNLOAD FOR ROW 530
# /papers/w9425
# else
# 531
# HAVE YET TO DO DOWNLOAD FOR ROW 531
# /papers/w9013
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 532
# HAVE YET TO DO DOWNLOAD FOR ROW 532
# /papers/w8336
# else
# 533
# HAVE YET TO DO DOWNLOAD FOR ROW 533
# /papers/w8337
# else
# 534
# HAVE YET TO DO DOWNLOAD FOR ROW 534
# /papers/w7959
# else
# 535
# HAVE YET TO DO DOWNLOAD FOR ROW 535
# /papers/w7890
# else
# 536
# HAVE YET TO DO DOWNLOAD FOR ROW 536
# /papers/w7637
# else
# 537
# HAVE YET TO DO DOWNLOAD FOR ROW 537
# /papers/w7557
# else
# 538
# HAVE YET TO DO DOWNLOAD FOR ROW 538
# /papers/w5956
# else
# 539
# HAVE YET TO DO DOWNLOAD FOR ROW 539
# /papers/w29722
# else
# 540
# HAVE YET TO DO DOWNLOAD FOR ROW 540
# /papers/w28268
# else
# 541
# HAVE YET TO DO DOWNLOAD FOR ROW 541
# /papers/w26942
# else
# 542
# HAVE YET TO DO DOWNLOAD FOR ROW 542
# /papers/w26926
# else
# 543
# HAVE YET TO DO DOWNLOAD FOR ROW 543
# /papers/w26416
# else
# 544
# HAVE YET TO DO DOWNLOAD FOR ROW 544
# /papers/w24019
# else
# 545
# HAVE YET TO DO DOWNLOAD FOR ROW 545
# /papers/w23971
# else
# 546
# HAVE YET TO DO DOWNLOAD FOR ROW 546
# /papers/w23465
# else
# 547
# HAVE YET TO DO DOWNLOAD FOR ROW 547
# /papers/w20653
# else
# 548
# HAVE YET TO DO DOWNLOAD FOR ROW 548
# /papers/w19860
# else
# 549
# HAVE YET TO DO DOWNLOAD FOR ROW 549
# /papers/w19599
# else
# 550
# HAVE YET TO DO DOWNLOAD FOR ROW 550
# /papers/w19493
# else
# 551
# HAVE YET TO DO DOWNLOAD FOR ROW 551
# /papers/w17922
# else
# 552
# HAVE YET TO DO DOWNLOAD FOR ROW 552
# /papers/w17633
# else
# 553
# HAVE YET TO DO DOWNLOAD FOR ROW 553
# /papers/w17343
# else
# 554
# HAVE YET TO DO DOWNLOAD FOR ROW 554
# /papers/w14675
# else
# 555
# HAVE YET TO DO DOWNLOAD FOR ROW 555
# /papers/w14641
# else
# 556
# HAVE YET TO DO DOWNLOAD FOR ROW 556
# /papers/w10621
# else
# 557
# HAVE YET TO DO DOWNLOAD FOR ROW 557
# /papers/w28556
# else
# 558
# HAVE YET TO DO DOWNLOAD FOR ROW 558
# /papers/w28382
# else
# 559
# HAVE YET TO DO DOWNLOAD FOR ROW 559
# /papers/w26325
# else
# 560
# HAVE YET TO DO DOWNLOAD FOR ROW 560
# /papers/w25834
# else
# 561
# HAVE YET TO DO DOWNLOAD FOR ROW 561
# /papers/w23514
# else
# 562
# HAVE YET TO DO DOWNLOAD FOR ROW 562
# /papers/w22641
# else
# 563
# HAVE YET TO DO DOWNLOAD FOR ROW 563
# /papers/w22248
# else
# 564
# HAVE YET TO DO DOWNLOAD FOR ROW 564
# /papers/w21571
# else
# 565
# HAVE YET TO DO DOWNLOAD FOR ROW 565
# /papers/w21022
# else
# 566
# HAVE YET TO DO DOWNLOAD FOR ROW 566
# /papers/w18893
# else
# 567
# HAVE YET TO DO DOWNLOAD FOR ROW 567
# /papers/w17105
# else
# 568
# HAVE YET TO DO DOWNLOAD FOR ROW 568
# /papers/w16846
# else
# 569
# HAVE YET TO DO DOWNLOAD FOR ROW 569
# /papers/w14667
# else
# 570
# HAVE YET TO DO DOWNLOAD FOR ROW 570
# /papers/w13826
# else
# 571
# HAVE YET TO DO DOWNLOAD FOR ROW 571
# /papers/w13188
# else
# 572
# HAVE YET TO DO DOWNLOAD FOR ROW 572
# /papers/w11832
# else
# 573
# HAVE YET TO DO DOWNLOAD FOR ROW 573
# /papers/w11135
# else
# 574
# HAVE YET TO DO DOWNLOAD FOR ROW 574
# /papers/w9782
# else
# 575
# HAVE YET TO DO DOWNLOAD FOR ROW 575
# /papers/w9455
# else
# 576
# HAVE YET TO DO DOWNLOAD FOR ROW 576
# /papers/w8658
# else
# 577
# HAVE YET TO DO DOWNLOAD FOR ROW 577
# /papers/w8419
# else
# 578
# HAVE YET TO DO DOWNLOAD FOR ROW 578
# /papers/w7937
# else
# 579
# HAVE YET TO DO DOWNLOAD FOR ROW 579
# /papers/w7370
# else
# 580
# HAVE YET TO DO DOWNLOAD FOR ROW 580
# /papers/w7371
# else
# 581
# HAVE YET TO DO DOWNLOAD FOR ROW 581
# /papers/w7138
# else
# 582
# HAVE YET TO DO DOWNLOAD FOR ROW 582
# /papers/w29486
# else
# 583
# HAVE YET TO DO DOWNLOAD FOR ROW 583
# /papers/w28672
# else
# 584
# HAVE YET TO DO DOWNLOAD FOR ROW 584
# /papers/w25784
# else
# 585
# HAVE YET TO DO DOWNLOAD FOR ROW 585
# /papers/w25378
# else
# 586
# HAVE YET TO DO DOWNLOAD FOR ROW 586
# /papers/w21747
# else
# 587
# HAVE YET TO DO DOWNLOAD FOR ROW 587
# /papers/w20499
# else
# 588
# HAVE YET TO DO DOWNLOAD FOR ROW 588
# /papers/w19412
# else
# 589
# HAVE YET TO DO DOWNLOAD FOR ROW 589
# /papers/w17474
# else
# 590
# HAVE YET TO DO DOWNLOAD FOR ROW 590
# /papers/w13651
# else
# 591
# HAVE YET TO DO DOWNLOAD FOR ROW 591
# /papers/w11773
# else
# 592
# HAVE YET TO DO DOWNLOAD FOR ROW 592
# /papers/w11158
# else
# 593
# HAVE YET TO DO DOWNLOAD FOR ROW 593
# /papers/w9987
# else
# 594
# HAVE YET TO DO DOWNLOAD FOR ROW 594
# /papers/w7467
# else
# 595
# HAVE YET TO DO DOWNLOAD FOR ROW 595
# /papers/w7043
# else
# 596
# HAVE YET TO DO DOWNLOAD FOR ROW 596
# /papers/w5941
# else
# 597
# HAVE YET TO DO DOWNLOAD FOR ROW 597
# /papers/w5107
# else
# 598
# HAVE YET TO DO DOWNLOAD FOR ROW 598
# /papers/w4027
# else
# 599
# HAVE YET TO DO DOWNLOAD FOR ROW 599
# /papers/w3893
# else
# 600
# HAVE YET TO DO DOWNLOAD FOR ROW 600
# /papers/w3433
# else
# 601
# HAVE YET TO DO DOWNLOAD FOR ROW 601
# /papers/w3026
# else
# 602
# HAVE YET TO DO DOWNLOAD FOR ROW 602
# /papers/w2732
# else
# 603
# HAVE YET TO DO DOWNLOAD FOR ROW 603
# /papers/w2049
# else
# 604
# HAVE YET TO DO DOWNLOAD FOR ROW 604
# /papers/w1718
# else
# 605
# HAVE YET TO DO DOWNLOAD FOR ROW 605
# /papers/w1660
# else
# 606
# HAVE YET TO DO DOWNLOAD FOR ROW 606
# /papers/w0953
# else
# 607
# HAVE YET TO DO DOWNLOAD FOR ROW 607
# /papers/w0552
# else
# 608
# HAVE YET TO DO DOWNLOAD FOR ROW 608
# /papers/w0198
# else
# 609
# HAVE YET TO DO DOWNLOAD FOR ROW 609
# /papers/w0117
# else
# 610
# HAVE YET TO DO DOWNLOAD FOR ROW 610
# /papers/w0285
# else
# 611
# HAVE YET TO DO DOWNLOAD FOR ROW 611
# /papers/w0161
# else
# 612
# HAVE YET TO DO DOWNLOAD FOR ROW 612
# /papers/w0059
# else
# 613
# HAVE YET TO DO DOWNLOAD FOR ROW 613
# /papers/w24685
# else
# 614
# HAVE YET TO DO DOWNLOAD FOR ROW 614
# /papers/w24223
# else
# 615
# HAVE YET TO DO DOWNLOAD FOR ROW 615
# /papers/w22825
# else
# 616
# HAVE YET TO DO DOWNLOAD FOR ROW 616
# /papers/w22275
# else
# 617
# HAVE YET TO DO DOWNLOAD FOR ROW 617
# /papers/w21466
# else
# 618
# HAVE YET TO DO DOWNLOAD FOR ROW 618
# /papers/w21241
# else
# 619
# HAVE YET TO DO DOWNLOAD FOR ROW 619
# /papers/w20568
# else
# 620
# HAVE YET TO DO DOWNLOAD FOR ROW 620
# /papers/w20550
# else
# 621
# HAVE YET TO DO DOWNLOAD FOR ROW 621
# /papers/w20101
# else
# 622
# HAVE YET TO DO DOWNLOAD FOR ROW 622
# /papers/w19411
# else
# 623
# HAVE YET TO DO DOWNLOAD FOR ROW 623
# /papers/w19118
# else
# 624
# HAVE YET TO DO DOWNLOAD FOR ROW 624
# /papers/w18901
# else
# 625
# HAVE YET TO DO DOWNLOAD FOR ROW 625
# /papers/w18159
# else
# 626
# HAVE YET TO DO DOWNLOAD FOR ROW 626
# /papers/w17651
# else
# 627
# HAVE YET TO DO DOWNLOAD FOR ROW 627
# /papers/w17291
# else
# 628
# HAVE YET TO DO DOWNLOAD FOR ROW 628
# /papers/w15790
# else
# 629
# HAVE YET TO DO DOWNLOAD FOR ROW 629
# /papers/w15110
# else
# 630
# HAVE YET TO DO DOWNLOAD FOR ROW 630
# /papers/w14950
# else
# 631
# HAVE YET TO DO DOWNLOAD FOR ROW 631
# /papers/w13500
# else
# 632
# HAVE YET TO DO DOWNLOAD FOR ROW 632
# /papers/w13006
# else
# 633
# HAVE YET TO DO DOWNLOAD FOR ROW 633
# /papers/w12710
# else
# 634
# HAVE YET TO DO DOWNLOAD FOR ROW 634
# /papers/w12521
# else
# 635
# HAVE YET TO DO DOWNLOAD FOR ROW 635
# /papers/w11496
# else
# 636
# HAVE YET TO DO DOWNLOAD FOR ROW 636
# /papers/w11451
# else
# 637
# HAVE YET TO DO DOWNLOAD FOR ROW 637
# /papers/w10776
# else
# 638
# HAVE YET TO DO DOWNLOAD FOR ROW 638
# /papers/w10565
# else
# 639
# HAVE YET TO DO DOWNLOAD FOR ROW 639
# /papers/w10548
# else
# 640
# HAVE YET TO DO DOWNLOAD FOR ROW 640
# /papers/w9240
# else
# 641
# HAVE YET TO DO DOWNLOAD FOR ROW 641
# /papers/w8787
# else
# 642
# HAVE YET TO DO DOWNLOAD FOR ROW 642
# /papers/w8754
# else
# 643
# HAVE YET TO DO DOWNLOAD FOR ROW 643
# /papers/w8149
# else
# 644
# HAVE YET TO DO DOWNLOAD FOR ROW 644
# /papers/w7697
# else
# 645
# HAVE YET TO DO DOWNLOAD FOR ROW 645
# /papers/w6853
# else
# 646
# HAVE YET TO DO DOWNLOAD FOR ROW 646
# /papers/w6355
# else
# 647
# HAVE YET TO DO DOWNLOAD FOR ROW 647
# /papers/w6132
# else
# 648
# HAVE YET TO DO DOWNLOAD FOR ROW 648
# /papers/w21849
# else
# 649
# HAVE YET TO DO DOWNLOAD FOR ROW 649
# /papers/w21061
# else
# 650
# HAVE YET TO DO DOWNLOAD FOR ROW 650
# /papers/w19949
# else
# 651
# HAVE YET TO DO DOWNLOAD FOR ROW 651
# /papers/w19266
# else
# 652
# HAVE YET TO DO DOWNLOAD FOR ROW 652
# /papers/w18674
# else
# 653
# HAVE YET TO DO DOWNLOAD FOR ROW 653
# /papers/w18375
# else
# 654
# HAVE YET TO DO DOWNLOAD FOR ROW 654
# /papers/w18350
# else
# 655
# HAVE YET TO DO DOWNLOAD FOR ROW 655
# /papers/w15547
# else
# 656
# HAVE YET TO DO DOWNLOAD FOR ROW 656
# /papers/w14606
# else
# 657
# HAVE YET TO DO DOWNLOAD FOR ROW 657
# /papers/w13725
# else
# 658
# HAVE YET TO DO DOWNLOAD FOR ROW 658
# /papers/w11740
# else
# 659
# HAVE YET TO DO DOWNLOAD FOR ROW 659
# /papers/w11663
# else
# 660
# HAVE YET TO DO DOWNLOAD FOR ROW 660
# /papers/w10004
# else
# 661
# HAVE YET TO DO DOWNLOAD FOR ROW 661
# /papers/w7964
# else
# 662
# HAVE YET TO DO DOWNLOAD FOR ROW 662
# /papers/w7737
# else
# 663
# HAVE YET TO DO DOWNLOAD FOR ROW 663
# /papers/w7545
# else
# 664
# HAVE YET TO DO DOWNLOAD FOR ROW 664
# /papers/w6776
# else
# 665
# HAVE YET TO DO DOWNLOAD FOR ROW 665
# /papers/w6715
# else
# 666
# HAVE YET TO DO DOWNLOAD FOR ROW 666
# /papers/w6299
# else
# 667
# HAVE YET TO DO DOWNLOAD FOR ROW 667
# /papers/w6166
# else
# 668
# HAVE YET TO DO DOWNLOAD FOR ROW 668
# /papers/w4255
# else
# 669
# HAVE YET TO DO DOWNLOAD FOR ROW 669
# /papers/w29151
# else
# 670
# HAVE YET TO DO DOWNLOAD FOR ROW 670
# /papers/w28664
# else
# 671
# HAVE YET TO DO DOWNLOAD FOR ROW 671
# /papers/w27613
# else
# 672
# HAVE YET TO DO DOWNLOAD FOR ROW 672
# /papers/w26989
# else
# 673
# HAVE YET TO DO DOWNLOAD FOR ROW 673
# /papers/w25679
# else
# 674
# HAVE YET TO DO DOWNLOAD FOR ROW 674
# /papers/w25389
# else
# 675
# HAVE YET TO DO DOWNLOAD FOR ROW 675
# /papers/w25329
# else
# 676
# HAVE YET TO DO DOWNLOAD FOR ROW 676
# /papers/w24771
# else
# 677
# HAVE YET TO DO DOWNLOAD FOR ROW 677
# /papers/w24451
# else
# 678
# HAVE YET TO DO DOWNLOAD FOR ROW 678
# /papers/w22015
# else
# 679
# HAVE YET TO DO DOWNLOAD FOR ROW 679
# /papers/w22014
# else
# 680
# HAVE YET TO DO DOWNLOAD FOR ROW 680
# /papers/w20256
# else
# 681
# HAVE YET TO DO DOWNLOAD FOR ROW 681
# /papers/w19023
# else
# 682
# HAVE YET TO DO DOWNLOAD FOR ROW 682
# /papers/w18883
# else
# 683
# HAVE YET TO DO DOWNLOAD FOR ROW 683
# /papers/w17541
# else
# 684
# HAVE YET TO DO DOWNLOAD FOR ROW 684
# /papers/w16765
# else
# 685
# HAVE YET TO DO DOWNLOAD FOR ROW 685
# /papers/w14681
# else
# 686
# HAVE YET TO DO DOWNLOAD FOR ROW 686
# /papers/w13926
# else
# 687
# HAVE YET TO DO DOWNLOAD FOR ROW 687
# /papers/w13890
# else
# 688
# HAVE YET TO DO DOWNLOAD FOR ROW 688
# /papers/w13738
# else
# 689
# HAVE YET TO DO DOWNLOAD FOR ROW 689
# /papers/w12274
# else
# 690
# HAVE YET TO DO DOWNLOAD FOR ROW 690
# /papers/w11892
# else
# 691
# HAVE YET TO DO DOWNLOAD FOR ROW 691
# /papers/w11126
# else
# 692
# HAVE YET TO DO DOWNLOAD FOR ROW 692
# /papers/w9873
# else
# 693
# HAVE YET TO DO DOWNLOAD FOR ROW 693
# /papers/w8841
# else
# 694
# HAVE YET TO DO DOWNLOAD FOR ROW 694
# /papers/w8211
# else
# 695
# HAVE YET TO DO DOWNLOAD FOR ROW 695
# /papers/w7952
# else
# 696
# HAVE YET TO DO DOWNLOAD FOR ROW 696
# /papers/w7931
# else
# 697
# HAVE YET TO DO DOWNLOAD FOR ROW 697
# /papers/w7924
# else
# 698
# HAVE YET TO DO DOWNLOAD FOR ROW 698
# /papers/w7604
# else
# 699
# HAVE YET TO DO DOWNLOAD FOR ROW 699
# /papers/w7594
# else
# 700
# HAVE YET TO DO DOWNLOAD FOR ROW 700
# /papers/w6900
# else
# 701
# HAVE YET TO DO DOWNLOAD FOR ROW 701
# /papers/w6832
# else
# 702
# HAVE YET TO DO DOWNLOAD FOR ROW 702
# /papers/w6830
# else
# 703
# HAVE YET TO DO DOWNLOAD FOR ROW 703
# /papers/w6807
# else
# 704
# HAVE YET TO DO DOWNLOAD FOR ROW 704
# /papers/w29151
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 705
# HAVE YET TO DO DOWNLOAD FOR ROW 705
# /papers/w28664
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 706
# HAVE YET TO DO DOWNLOAD FOR ROW 706
# /papers/w27613
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 707
# HAVE YET TO DO DOWNLOAD FOR ROW 707
# /papers/w26989
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 708
# HAVE YET TO DO DOWNLOAD FOR ROW 708
# /papers/w25679
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 709
# HAVE YET TO DO DOWNLOAD FOR ROW 709
# /papers/w25389
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 710
# HAVE YET TO DO DOWNLOAD FOR ROW 710
# /papers/w25329
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 711
# HAVE YET TO DO DOWNLOAD FOR ROW 711
# /papers/w24771
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 712
# HAVE YET TO DO DOWNLOAD FOR ROW 712
# /papers/w24451
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 713
# HAVE YET TO DO DOWNLOAD FOR ROW 713
# /papers/w22014
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 714
# HAVE YET TO DO DOWNLOAD FOR ROW 714
# /papers/w22015
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 715
# HAVE YET TO DO DOWNLOAD FOR ROW 715
# /papers/w20256
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 716
# HAVE YET TO DO DOWNLOAD FOR ROW 716
# /papers/w19023
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 717
# HAVE YET TO DO DOWNLOAD FOR ROW 717
# /papers/w18883
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 718
# HAVE YET TO DO DOWNLOAD FOR ROW 718
# /papers/w17541
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 719
# HAVE YET TO DO DOWNLOAD FOR ROW 719
# /papers/w16765
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 720
# HAVE YET TO DO DOWNLOAD FOR ROW 720
# /papers/w14681
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 721
# HAVE YET TO DO DOWNLOAD FOR ROW 721
# /papers/w13926
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 722
# HAVE YET TO DO DOWNLOAD FOR ROW 722
# /papers/w13890
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 723
# HAVE YET TO DO DOWNLOAD FOR ROW 723
# /papers/w13738
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 724
# HAVE YET TO DO DOWNLOAD FOR ROW 724
# /papers/w12274
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 725
# HAVE YET TO DO DOWNLOAD FOR ROW 725
# /papers/w11892
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 726
# HAVE YET TO DO DOWNLOAD FOR ROW 726
# /papers/w11126
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 727
# HAVE YET TO DO DOWNLOAD FOR ROW 727
# /papers/w9873
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 728
# HAVE YET TO DO DOWNLOAD FOR ROW 728
# /papers/w8841
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 729
# HAVE YET TO DO DOWNLOAD FOR ROW 729
# /papers/w8211
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 730
# HAVE YET TO DO DOWNLOAD FOR ROW 730
# /papers/w7952
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 731
# HAVE YET TO DO DOWNLOAD FOR ROW 731
# /papers/w7931
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 732
# HAVE YET TO DO DOWNLOAD FOR ROW 732
# /papers/w7924
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 733
# HAVE YET TO DO DOWNLOAD FOR ROW 733
# /papers/w7604
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 734
# HAVE YET TO DO DOWNLOAD FOR ROW 734
# /papers/w7594
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 735
# HAVE YET TO DO DOWNLOAD FOR ROW 735
# /papers/w6900
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 736
# HAVE YET TO DO DOWNLOAD FOR ROW 736
# /papers/w6832
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 737
# HAVE YET TO DO DOWNLOAD FOR ROW 737
# /papers/w6830
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 738
# HAVE YET TO DO DOWNLOAD FOR ROW 738
# /papers/w6807
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 739
# HAVE YET TO DO DOWNLOAD FOR ROW 739
# /papers/w29693
# else
# 740
# HAVE YET TO DO DOWNLOAD FOR ROW 740
# /papers/w28239
# else
# 741
# HAVE YET TO DO DOWNLOAD FOR ROW 741
# /papers/w27658
# else
# 742
# HAVE YET TO DO DOWNLOAD FOR ROW 742
# ...
# /papers/w20192
# else
# 11024
# HAVE YET TO DO DOWNLOAD FOR ROW 11024
# /papers/w19879
# else
# 11025
# HAVE YET TO DO DOWNLOAD FOR ROW 11025
# /papers/w18594
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11026
# HAVE YET TO DO DOWNLOAD FOR ROW 11026
# /papers/w18418
# else
# 11027
# HAVE YET TO DO DOWNLOAD FOR ROW 11027
# /papers/w16234
# else
# 11028
# HAVE YET TO DO DOWNLOAD FOR ROW 11028
# /papers/w16235
# else
# 11029
# HAVE YET TO DO DOWNLOAD FOR ROW 11029
# /papers/w13563
# else
# 11030
# HAVE YET TO DO DOWNLOAD FOR ROW 11030
# /papers/w13564
# else
# 11031
# HAVE YET TO DO DOWNLOAD FOR ROW 11031
# /papers/w12776
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11032
# HAVE YET TO DO DOWNLOAD FOR ROW 11032
# /papers/w11781
# else
# 11033
# HAVE YET TO DO DOWNLOAD FOR ROW 11033
# /papers/w11780
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11034
# HAVE YET TO DO DOWNLOAD FOR ROW 11034
# /papers/w11284
# else
# 11035
# HAVE YET TO DO DOWNLOAD FOR ROW 11035
# /papers/w10754
# else
# 11036
# HAVE YET TO DO DOWNLOAD FOR ROW 11036
# /papers/w10341
# else
# 11037
# HAVE YET TO DO DOWNLOAD FOR ROW 11037
# /papers/w10094
# else
# 11038
# HAVE YET TO DO DOWNLOAD FOR ROW 11038
# /papers/w9694
# else
# 11039
# HAVE YET TO DO DOWNLOAD FOR ROW 11039
# /papers/w9696
# else
# 11040
# HAVE YET TO DO DOWNLOAD FOR ROW 11040
# /papers/w9697
# else
# 11041
# HAVE YET TO DO DOWNLOAD FOR ROW 11041
# /papers/w9698
# else
# 11042
# HAVE YET TO DO DOWNLOAD FOR ROW 11042
# /papers/w9700
# else
# 11043
# HAVE YET TO DO DOWNLOAD FOR ROW 11043
# /papers/w9695
# else
# 11044
# HAVE YET TO DO DOWNLOAD FOR ROW 11044
# /papers/w9699
# else
# 11045
# HAVE YET TO DO DOWNLOAD FOR ROW 11045
# /papers/w9622
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11046
# HAVE YET TO DO DOWNLOAD FOR ROW 11046
# /papers/w9483
# else
# 11047
# HAVE YET TO DO DOWNLOAD FOR ROW 11047
# /papers/w9335
# else
# 11048
# HAVE YET TO DO DOWNLOAD FOR ROW 11048
# /papers/w8688
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11049
# HAVE YET TO DO DOWNLOAD FOR ROW 11049
# /papers/w7106
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11050
# HAVE YET TO DO DOWNLOAD FOR ROW 11050
# /papers/w6993
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11051
# HAVE YET TO DO DOWNLOAD FOR ROW 11051
# /papers/w7051
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11052
# HAVE YET TO DO DOWNLOAD FOR ROW 11052
# /papers/w6956
# else
# 11053
# HAVE YET TO DO DOWNLOAD FOR ROW 11053
# /papers/w6945
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11054
# HAVE YET TO DO DOWNLOAD FOR ROW 11054
# /papers/w6960
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11055
# HAVE YET TO DO DOWNLOAD FOR ROW 11055
# /papers/w6259
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11056
# HAVE YET TO DO DOWNLOAD FOR ROW 11056
# /papers/w6251
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11057
# HAVE YET TO DO DOWNLOAD FOR ROW 11057
# /papers/w5461
# else
# 11058
# HAVE YET TO DO DOWNLOAD FOR ROW 11058
# /papers/w4586
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11059
# HAVE YET TO DO DOWNLOAD FOR ROW 11059
# /papers/w4457
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11060
# HAVE YET TO DO DOWNLOAD FOR ROW 11060
# /papers/w4287
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11061
# HAVE YET TO DO DOWNLOAD FOR ROW 11061
# /papers/w4203
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11062
# HAVE YET TO DO DOWNLOAD FOR ROW 11062
# /papers/w4176
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11063
# HAVE YET TO DO DOWNLOAD FOR ROW 11063
# /papers/w4012
# else
# 11064
# HAVE YET TO DO DOWNLOAD FOR ROW 11064
# /papers/w3868
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11065
# HAVE YET TO DO DOWNLOAD FOR ROW 11065
# /papers/w3822
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11066
# HAVE YET TO DO DOWNLOAD FOR ROW 11066
# /papers/w3696
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11067
# HAVE YET TO DO DOWNLOAD FOR ROW 11067
# /papers/w3560
# else
# 11068
# HAVE YET TO DO DOWNLOAD FOR ROW 11068
# /papers/w3429
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11069
# HAVE YET TO DO DOWNLOAD FOR ROW 11069
# /papers/w3232
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11070
# HAVE YET TO DO DOWNLOAD FOR ROW 11070
# /papers/w3061
# else
# 11071
# HAVE YET TO DO DOWNLOAD FOR ROW 11071
# /papers/w3062
# else
# 11072
# HAVE YET TO DO DOWNLOAD FOR ROW 11072
# /papers/w3005
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11073
# HAVE YET TO DO DOWNLOAD FOR ROW 11073
# /papers/w1219
# else
# 11074
# HAVE YET TO DO DOWNLOAD FOR ROW 11074
# /papers/w1220
# else
# 11075
# HAVE YET TO DO DOWNLOAD FOR ROW 11075
# /papers/w1218
# else
# 11076
# HAVE YET TO DO DOWNLOAD FOR ROW 11076
# /papers/w0939
# else
# 11077
# HAVE YET TO DO DOWNLOAD FOR ROW 11077
# /papers/w0932
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11078
# HAVE YET TO DO DOWNLOAD FOR ROW 11078
# /papers/w0742
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11079
# HAVE YET TO DO DOWNLOAD FOR ROW 11079
# /papers/w0741
# else
# 11080
# HAVE YET TO DO DOWNLOAD FOR ROW 11080
# /papers/w0727
# else
# 11081
# HAVE YET TO DO DOWNLOAD FOR ROW 11081
# /papers/w0662
# else
# 11082
# HAVE YET TO DO DOWNLOAD FOR ROW 11082
# /papers/w29180
# else
# 11083
# HAVE YET TO DO DOWNLOAD FOR ROW 11083
# /papers/w29018
# else
# 11084
# HAVE YET TO DO DOWNLOAD FOR ROW 11084
# /papers/w28492
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11085
# HAVE YET TO DO DOWNLOAD FOR ROW 11085
# /papers/w28168
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11086
# HAVE YET TO DO DOWNLOAD FOR ROW 11086
# /papers/w28128
# else
# 11087
# HAVE YET TO DO DOWNLOAD FOR ROW 11087
# /papers/w28085
# else
# 11088
# HAVE YET TO DO DOWNLOAD FOR ROW 11088
# /papers/w26775
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11089
# HAVE YET TO DO DOWNLOAD FOR ROW 11089
# /papers/w25119
# else
# 11090
# HAVE YET TO DO DOWNLOAD FOR ROW 11090
# /papers/w25058
# else
# 11091
# HAVE YET TO DO DOWNLOAD FOR ROW 11091
# /papers/w24786
# else
# 11092
# HAVE YET TO DO DOWNLOAD FOR ROW 11092
# /papers/w24680
# else
# 11093
# HAVE YET TO DO DOWNLOAD FOR ROW 11093
# /papers/w24206
# else
# 11094
# HAVE YET TO DO DOWNLOAD FOR ROW 11094
# /papers/w22219
# else
# 11095
# HAVE YET TO DO DOWNLOAD FOR ROW 11095
# /papers/w22220
# else
# 11096
# HAVE YET TO DO DOWNLOAD FOR ROW 11096
# /papers/w21012
# else
# 11097
# HAVE YET TO DO DOWNLOAD FOR ROW 11097
# /papers/w18862
# else
# 11098
# HAVE YET TO DO DOWNLOAD FOR ROW 11098
# /papers/w9833
# else
# 11099
# HAVE YET TO DO DOWNLOAD FOR ROW 11099
# /papers/w28491
# else
# 11100
# HAVE YET TO DO DOWNLOAD FOR ROW 11100
# /papers/w21188
# else
# 11101
# HAVE YET TO DO DOWNLOAD FOR ROW 11101
# /papers/w21186
# else
# 11102
# HAVE YET TO DO DOWNLOAD FOR ROW 11102
# /papers/w18636
# else
# 11103
# HAVE YET TO DO DOWNLOAD FOR ROW 11103
# /papers/w16735
# else
# 11104
# HAVE YET TO DO DOWNLOAD FOR ROW 11104
# /papers/w14152
# else
# 11105
# HAVE YET TO DO DOWNLOAD FOR ROW 11105
# /papers/w13321
# else
# 11106
# HAVE YET TO DO DOWNLOAD FOR ROW 11106
# /papers/w13253
# else
# 11107
# HAVE YET TO DO DOWNLOAD FOR ROW 11107
# /papers/w12209
# else
# 11108
# HAVE YET TO DO DOWNLOAD FOR ROW 11108
# /papers/w11317
# else
# 11109
# HAVE YET TO DO DOWNLOAD FOR ROW 11109
# /papers/w5929
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11110
# HAVE YET TO DO DOWNLOAD FOR ROW 11110
# /papers/w5770
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11111
# HAVE YET TO DO DOWNLOAD FOR ROW 11111
# /papers/w5561
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11112
# HAVE YET TO DO DOWNLOAD FOR ROW 11112
# /papers/w25094
# else
# 11113
# HAVE YET TO DO DOWNLOAD FOR ROW 11113
# /papers/w25095
# else
# 11114
# HAVE YET TO DO DOWNLOAD FOR ROW 11114
# /papers/w19873
# else
# 11115
# HAVE YET TO DO DOWNLOAD FOR ROW 11115
# /papers/w14183
# else
# 11116
# HAVE YET TO DO DOWNLOAD FOR ROW 11116
# /papers/w14115
# else
# 11117
# HAVE YET TO DO DOWNLOAD FOR ROW 11117
# /papers/w10972
# else
# 11118
# HAVE YET TO DO DOWNLOAD FOR ROW 11118
# /papers/w10943
# else
# 11119
# HAVE YET TO DO DOWNLOAD FOR ROW 11119
# /papers/w5461
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11120
# HAVE YET TO DO DOWNLOAD FOR ROW 11120
# /papers/w20116
# else
# 11121
# HAVE YET TO DO DOWNLOAD FOR ROW 11121
# /papers/w15585
# else
# 11122
# HAVE YET TO DO DOWNLOAD FOR ROW 11122
# /papers/w15571
# else
# 11123
# HAVE YET TO DO DOWNLOAD FOR ROW 11123
# /papers/w15422
# else
# 11124
# HAVE YET TO DO DOWNLOAD FOR ROW 11124
# /papers/w13599
# else
# 11125
# HAVE YET TO DO DOWNLOAD FOR ROW 11125
# /papers/w12582
# else
# 11126
# HAVE YET TO DO DOWNLOAD FOR ROW 11126
# /papers/w12348
# else
# 11127
# HAVE YET TO DO DOWNLOAD FOR ROW 11127
# /papers/w12294
# else
# 11128
# HAVE YET TO DO DOWNLOAD FOR ROW 11128
# /papers/w12086
# else
# 11129
# HAVE YET TO DO DOWNLOAD FOR ROW 11129
# /papers/w11935
# else
# 11130
# HAVE YET TO DO DOWNLOAD FOR ROW 11130
# /papers/w11934
# else
# 11131
# HAVE YET TO DO DOWNLOAD FOR ROW 11131
# /papers/w11859
# else
# 11132
# HAVE YET TO DO DOWNLOAD FOR ROW 11132
# /papers/w11863
# else
# 11133
# HAVE YET TO DO DOWNLOAD FOR ROW 11133
# /papers/w11659
# else
# 11134
# HAVE YET TO DO DOWNLOAD FOR ROW 11134
# /papers/w10266
# else
# 11135
# HAVE YET TO DO DOWNLOAD FOR ROW 11135
# /papers/w10199
# else
# 11136
# HAVE YET TO DO DOWNLOAD FOR ROW 11136
# /papers/w9487
# else
# 11137
# HAVE YET TO DO DOWNLOAD FOR ROW 11137
# /papers/w5246
# else
# 11138
# HAVE YET TO DO DOWNLOAD FOR ROW 11138
# /papers/w4891
# else
# 11139
# HAVE YET TO DO DOWNLOAD FOR ROW 11139
# /papers/w3494
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11140
# HAVE YET TO DO DOWNLOAD FOR ROW 11140
# /papers/w0394
# else
# 11141
# HAVE YET TO DO DOWNLOAD FOR ROW 11141
# /papers/w0371
# else
# 11142
# HAVE YET TO DO DOWNLOAD FOR ROW 11142
# /papers/w28765
# else
# 11143
# HAVE YET TO DO DOWNLOAD FOR ROW 11143
# /papers/w26254
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11144
# HAVE YET TO DO DOWNLOAD FOR ROW 11144
# /papers/w22742
# else
# 11145
# HAVE YET TO DO DOWNLOAD FOR ROW 11145
# /papers/w22518
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11146
# HAVE YET TO DO DOWNLOAD FOR ROW 11146
# /papers/w17807
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11147
# HAVE YET TO DO DOWNLOAD FOR ROW 11147
# /papers/w14577
# else
# 11148
# HAVE YET TO DO DOWNLOAD FOR ROW 11148
# /papers/w14341
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11149
# HAVE YET TO DO DOWNLOAD FOR ROW 11149
# /papers/w19952
# else
# 11150
# HAVE YET TO DO DOWNLOAD FOR ROW 11150
# /papers/w17237
# else
# 11151
# HAVE YET TO DO DOWNLOAD FOR ROW 11151
# /papers/w16932
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11152
# HAVE YET TO DO DOWNLOAD FOR ROW 11152
# /papers/w15968
# else
# 11153
# HAVE YET TO DO DOWNLOAD FOR ROW 11153
# /papers/w15472
# else
# 11154
# HAVE YET TO DO DOWNLOAD FOR ROW 11154
# /papers/w14549
# else
# 11155
# HAVE YET TO DO DOWNLOAD FOR ROW 11155
# /papers/w14179
# else
# 11156
# HAVE YET TO DO DOWNLOAD FOR ROW 11156
# /papers/w13265
# else
# 11157
# HAVE YET TO DO DOWNLOAD FOR ROW 11157
# /papers/w11536
# else
# 11158
# HAVE YET TO DO DOWNLOAD FOR ROW 11158
# /papers/w11108
# else
# 11159
# HAVE YET TO DO DOWNLOAD FOR ROW 11159
# /papers/w10308
# else
# 11160
# HAVE YET TO DO DOWNLOAD FOR ROW 11160
# /papers/w9603
# else
# 11161
# HAVE YET TO DO DOWNLOAD FOR ROW 11161
# /papers/w9362
# else
# 11162
# HAVE YET TO DO DOWNLOAD FOR ROW 11162
# /papers/w9340
# else
# 11163
# HAVE YET TO DO DOWNLOAD FOR ROW 11163
# /papers/w9302
# else
# 11164
# HAVE YET TO DO DOWNLOAD FOR ROW 11164
# /papers/w9010
# else
# 11165
# HAVE YET TO DO DOWNLOAD FOR ROW 11165
# /papers/w5653
# else
# 11166
# HAVE YET TO DO DOWNLOAD FOR ROW 11166
# /papers/w4371
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11167
# HAVE YET TO DO DOWNLOAD FOR ROW 11167
# /papers/w3428
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11168
# HAVE YET TO DO DOWNLOAD FOR ROW 11168
# /papers/w29332
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11169
# HAVE YET TO DO DOWNLOAD FOR ROW 11169
# /papers/w24731
# else
# 11170
# HAVE YET TO DO DOWNLOAD FOR ROW 11170
# /papers/w24615
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11171
# HAVE YET TO DO DOWNLOAD FOR ROW 11171
# /papers/w23421
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11172
# HAVE YET TO DO DOWNLOAD FOR ROW 11172
# /papers/w22511
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11173
# HAVE YET TO DO DOWNLOAD FOR ROW 11173
# /papers/w21032
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11174
# HAVE YET TO DO DOWNLOAD FOR ROW 11174
# /papers/w26219
# else
# 11175
# HAVE YET TO DO DOWNLOAD FOR ROW 11175
# /papers/w25323
# else
# 11176
# HAVE YET TO DO DOWNLOAD FOR ROW 11176
# /papers/w25007
# else
# 11177
# HAVE YET TO DO DOWNLOAD FOR ROW 11177
# /papers/w24774
# else
# 11178
# HAVE YET TO DO DOWNLOAD FOR ROW 11178
# /papers/w24064
# else
# 11179
# HAVE YET TO DO DOWNLOAD FOR ROW 11179
# /papers/w22870
# else
# 11180
# HAVE YET TO DO DOWNLOAD FOR ROW 11180
# /papers/w22238
# else
# 11181
# HAVE YET TO DO DOWNLOAD FOR ROW 11181
# /papers/w21802
# else
# 11182
# HAVE YET TO DO DOWNLOAD FOR ROW 11182
# /papers/w21066
# else
# 11183
# HAVE YET TO DO DOWNLOAD FOR ROW 11183
# /papers/w19991
# else
# 11184
# HAVE YET TO DO DOWNLOAD FOR ROW 11184
# /papers/w19975
# else
# 11185
# HAVE YET TO DO DOWNLOAD FOR ROW 11185
# /papers/w19747
# else
# 11186
# HAVE YET TO DO DOWNLOAD FOR ROW 11186
# /papers/w18886
# else
# 11187
# HAVE YET TO DO DOWNLOAD FOR ROW 11187
# /papers/w17940
# else
# 11188
# HAVE YET TO DO DOWNLOAD FOR ROW 11188
# /papers/w29566
# else
# 11189
# HAVE YET TO DO DOWNLOAD FOR ROW 11189
# /papers/w28799
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11190
# HAVE YET TO DO DOWNLOAD FOR ROW 11190
# /papers/w28262
# else
# 11191
# HAVE YET TO DO DOWNLOAD FOR ROW 11191
# /papers/w28138
# else
# 11192
# HAVE YET TO DO DOWNLOAD FOR ROW 11192
# /papers/w28011
# else
# 11193
# HAVE YET TO DO DOWNLOAD FOR ROW 11193
# /papers/w27860
# else
# 11194
# HAVE YET TO DO DOWNLOAD FOR ROW 11194
# /papers/w26110
# else
# 11195
# HAVE YET TO DO DOWNLOAD FOR ROW 11195
# /papers/w25540
# else
# 11196
# HAVE YET TO DO DOWNLOAD FOR ROW 11196
# /papers/w24379
# else
# 11197
# HAVE YET TO DO DOWNLOAD FOR ROW 11197
# /papers/w23625
# else
# 11198
# HAVE YET TO DO DOWNLOAD FOR ROW 11198
# /papers/w23057
# else
# 11199
# HAVE YET TO DO DOWNLOAD FOR ROW 11199
# /papers/w22633
# else
# 11200
# HAVE YET TO DO DOWNLOAD FOR ROW 11200
# /papers/w20956
# else
# 11201
# HAVE YET TO DO DOWNLOAD FOR ROW 11201
# /papers/w20496
# else
# 11202
# HAVE YET TO DO DOWNLOAD FOR ROW 11202
# /papers/w20135
# else
# 11203
# HAVE YET TO DO DOWNLOAD FOR ROW 11203
# /papers/w19827
# else
# 11204
# HAVE YET TO DO DOWNLOAD FOR ROW 11204
# /papers/w19696
# else
# 11205
# HAVE YET TO DO DOWNLOAD FOR ROW 11205
# /papers/w19682
# else
# 11206
# HAVE YET TO DO DOWNLOAD FOR ROW 11206
# /papers/w19119
# else
# 11207
# HAVE YET TO DO DOWNLOAD FOR ROW 11207
# /papers/w19106
# else
# 11208
# HAVE YET TO DO DOWNLOAD FOR ROW 11208
# /papers/w19069
# else
# 11209
# HAVE YET TO DO DOWNLOAD FOR ROW 11209
# /papers/w17952
# else
# 11210
# HAVE YET TO DO DOWNLOAD FOR ROW 11210
# /papers/w17883
# else
# 11211
# HAVE YET TO DO DOWNLOAD FOR ROW 11211
# /papers/w17829
# else
# 11212
# HAVE YET TO DO DOWNLOAD FOR ROW 11212
# /papers/w17804
# else
# 11213
# HAVE YET TO DO DOWNLOAD FOR ROW 11213
# /papers/w17475
# else
# 11214
# HAVE YET TO DO DOWNLOAD FOR ROW 11214
# /papers/w17028
# else
# 11215
# HAVE YET TO DO DOWNLOAD FOR ROW 11215
# /papers/w16205
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11216
# HAVE YET TO DO DOWNLOAD FOR ROW 11216
# /papers/w11892
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11217
# HAVE YET TO DO DOWNLOAD FOR ROW 11217
# /papers/w7780
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11218
# HAVE YET TO DO DOWNLOAD FOR ROW 11218
# /papers/w18222
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11219
# HAVE YET TO DO DOWNLOAD FOR ROW 11219
# /papers/w18050
# else
# 11220
# HAVE YET TO DO DOWNLOAD FOR ROW 11220
# /papers/w17857
# else
# 11221
# HAVE YET TO DO DOWNLOAD FOR ROW 11221
# /papers/w17829
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11222
# HAVE YET TO DO DOWNLOAD FOR ROW 11222
# /papers/w17732
# else
# 11223
# HAVE YET TO DO DOWNLOAD FOR ROW 11223
# /papers/w16949
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11224
# HAVE YET TO DO DOWNLOAD FOR ROW 11224
# /papers/w16329
# else
# 11225
# HAVE YET TO DO DOWNLOAD FOR ROW 11225
# /papers/w12751
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11226
# HAVE YET TO DO DOWNLOAD FOR ROW 11226
# /papers/w12200
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11227
# HAVE YET TO DO DOWNLOAD FOR ROW 11227
# /papers/w12073
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11228
# HAVE YET TO DO DOWNLOAD FOR ROW 11228
# /papers/w12083
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11229
# HAVE YET TO DO DOWNLOAD FOR ROW 11229
# /papers/w12060
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11230
# HAVE YET TO DO DOWNLOAD FOR ROW 11230
# /papers/w10504
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11231
# HAVE YET TO DO DOWNLOAD FOR ROW 11231
# /papers/w9587
# THIS PAPER HAS ALREADY BEEN COLLECTED ONCE BEFORE
# 11232
# HAVE YET TO DO DOWNLOAD FOR ROW 11232
# /papers/w8018
# else

# %%
all_papers_df.to_csv('all_papers_df_temp_backup.csv', index=False, encoding='utf-8')
